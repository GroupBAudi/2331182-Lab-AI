# %% [markdown]
# # Two-Stage Emotion Detection System
#
# This notebook implements a two-stage emotion detection system:
# - **Stage 1**: Detect faces using pre-trained YOLO
# - **Stage 2**: Classify emotions from detected face regions
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
import torch
from ultralytics import YOLO
import cv2
import numpy as np
from pathlib import Path
from PIL import Image
import shutil
from IPython.display import display, Image as IPImage, clear_output
import matplotlib.pyplot as plt

print("✓ Libraries imported successfully!")
# Out:
# ✓ Libraries imported successfully!

# %% [markdown]
# ## 2. TwoStageEmotionDetector Class

# %%
class TwoStageEmotionDetector:
    """
    Two-stage emotion detection system:
    Stage 1: Detect faces using pre-trained YOLO
    Stage 2: Classify emotions from detected face regions
    """
    
    def __init__(self, face_model='yolov8n-face.pt', emotion_model=None, device='cuda'):
        """
        Initialize the two-stage detector.
        
        Args:
            face_model: Pre-trained face detection model path
            emotion_model: Trained emotion classifier path (None for training mode)
            device: Computing device ('cuda' or 'cpu')
        """
        self.device = device if torch.cuda.is_available() else 'cpu'
        print(f"Using device: {self.device}")
        
        # Load face detection model
        print("Loading face detection model...")
        try:
            self.face_detector = YOLO(face_model)
            print(f"✓ Face detector loaded: {face_model}")
        except:
            print(f"⚠ {face_model} not found, falling back to yolov8n.pt")
            print("  For better results, download yolov8n-face.pt from:")
            print("  https://github.com/akanametov/yolov8-face")
            self.face_detector = YOLO('yolov8n.pt')
        
        # Load or initialize emotion classifier
        if emotion_model and Path(emotion_model).exists():
            self.emotion_classifier = YOLO(emotion_model)
            print(f"✓ Emotion classifier loaded: {emotion_model}")
        else:
            self.emotion_classifier = YOLO('yolov8n-cls.pt')
            print("✓ Emotion classifier initialized for training")
    
    def train_emotion_classifier(self, dataset_dir, epochs=20, imgsz=224, batch=64, patience=15):
        """
        Train the emotion classification model.
        """
        print(f"\n{'='*60}")
        print("Training Emotion Classifier")
        print(f"{'='*60}\n")
        
        results = self.emotion_classifier.train(
            data=dataset_dir,
            epochs=epochs,
            imgsz=imgsz,
            batch=batch,
            device=self.device,
            patience=patience,
            save=True,
            plots=True,
            project='emotion_runs',
            name='emotion_classifier'
        )
        
        print("\n✓ Training completed!")
        
        # Automatically copy best model to root directory
        best_model_path = Path('emotion_runs/emotion_classifier/weights/best.pt')
        root_model_path = Path('best_emotion_model.pt')
        
        if best_model_path.exists():
            shutil.copy2(best_model_path, root_model_path)
            print(f"✓ Best model automatically saved to: {root_model_path.absolute()}")
        
        return results
    
    def validate_emotion_classifier(self, dataset_dir):
        """Validate the trained emotion classifier."""
        print("\nValidating emotion classifier...")
        return self.emotion_classifier.val(data=dataset_dir)
    
    def detect_and_classify(self, image_path, conf_face=0.5, conf_emotion=0.3, 
                           save_output=False, output_path=None):
        """
        Perform two-stage emotion detection on an image.
        
        Returns:
            annotated_img: Image with bounding boxes and labels
            emotions_detected: List of detected emotions with metadata
        """
        # Load image
        if isinstance(image_path, str):
            img = cv2.imread(image_path)
            if img is None:
                print(f"Error: Could not read image {image_path}")
                return None, []
        else:
            img = image_path
        
        # Stage 1: Detect faces
        face_results = self.face_detector(img, conf=conf_face, verbose=False)
        
        # Check if any faces detected
        if (face_results is None or len(face_results) == 0 or 
            face_results[0].boxes is None or len(face_results[0].boxes) == 0):
            return img, []
        
        # Stage 2: Classify emotion for each detected face
        emotions_detected = []
        annotated_img = img.copy()
        
        for box in face_results[0].boxes:
            # Extract face region
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            face_crop = img[y1:y2, x1:x2]
            
            if face_crop.size == 0:
                continue
            
            # Classify emotion
            emotion_results = self.emotion_classifier(face_crop, conf=conf_emotion, verbose=False)
            
            if len(emotion_results) > 0:
                probs = emotion_results[0].probs
                top_class = probs.top1
                confidence = probs.top1conf.item()
                emotion = emotion_results[0].names[top_class]
                
                emotions_detected.append({
                    'emotion': emotion,
                    'confidence': confidence,
                    'bbox': [x1, y1, x2, y2]
                })
                
                # Annotate image
                color = self._get_emotion_color(emotion)
                cv2.rectangle(annotated_img, (x1, y1), (x2, y2), color, 2)
                
                # Draw label with background
                label = f"{emotion}: {confidence:.2%}"
                (label_w, label_h), _ = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.6, 2)
                cv2.rectangle(annotated_img, (x1, y1 - label_h - 10), (x1 + label_w, y1), color, -1)
                cv2.putText(annotated_img, label, (x1, y1 - 5),
                           cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)
        
        # Print results
        print(f"\nDetected {len(emotions_detected)} face(s):")
        for i, result in enumerate(emotions_detected, 1):
            print(f"  Face {i}: {result['emotion']} ({result['confidence']:.2%})")
        
        # Save output if requested
        if save_output and output_path:
            cv2.imwrite(output_path, annotated_img)
            print(f"\n✓ Saved annotated image to: {output_path}")
        
        return annotated_img, emotions_detected
    
    def process_video(self, video_source, output_path=None, conf_face=0.5, conf_emotion=0.3):
        """
        Process video file or webcam stream for emotion detection.
        """
        # Open video source
        if video_source == 'webcam':
            video_source = 0
        
        cap = cv2.VideoCapture(video_source)
        
        if not cap.isOpened():
            print(f"Error: Could not open video source {video_source}")
            return
        
        # Setup video writer if output requested
        if output_path:
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            fps = int(cap.get(cv2.CAP_PROP_FPS)) or 30
            width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
        
        print("\nProcessing video... Press 'q' to quit")
        frame_count = 0
        
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break
            
            frame_count += 1
            
            # Process frame
            annotated_frame, emotions = self.detect_and_classify(
                frame, conf_face=conf_face, conf_emotion=conf_emotion
            )
            
            # Always use the frame (annotated or original)
            display_frame = annotated_frame if annotated_frame is not None else frame
            
            # Add frame info overlay
            info_text = f"Frame: {frame_count} | Faces: {len(emotions) if emotions else 0}"
            cv2.putText(display_frame, info_text, (10, 30),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
            
            # Display frame
            cv2.imshow('Emotion Detection', display_frame)
            
            # Save frame if recording
            if output_path:
                out.write(display_frame)
            
            # Check for quit command (MUST be after imshow)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        
        # Cleanup
        cap.release()
        if output_path:
            out.release()
        cv2.destroyAllWindows()
        print(f"\n✓ Video processing completed! Processed {frame_count} frames")
    
    def _get_emotion_color(self, emotion):
        """Map emotions to BGR colors for visualization."""
        colors = {
            'angry': (0, 0, 255),        # Red
            'disgusted': (0, 128, 128),  # Teal
            'fearful': (128, 0, 128),    # Purple
            'happy': (0, 255, 0),        # Green
            'neutral': (128, 128, 128),  # Gray
            'sad': (255, 0, 0),          # Blue
            'surprised': (0, 255, 255),  # Yellow
            'nothing': (200, 200, 200)   # Light gray
        }
        return colors.get(emotion.lower(), (255, 255, 255))
    
    def export_emotion_model(self, format='onnx'):
        """Export emotion classifier to different formats."""
        print(f"Exporting emotion classifier to {format}...")
        self.emotion_classifier.export(format=format)
        
        # Copy exported model to root directory
        if format == 'onnx':
            onnx_path = Path('emotion_runs/emotion_classifier/weights/best.onnx')
            root_onnx_path = Path('best_emotion_model.onnx')
            if onnx_path.exists():
                shutil.copy2(onnx_path, root_onnx_path)
                print(f"✓ ONNX model saved to: {root_onnx_path.absolute()}")
        
        print("✓ Export completed!")


def check_trained_model():
    """Check if a trained emotion model already exists."""
    possible_paths = [
        Path('best_emotion_model.pt'),
        Path('emotion_runs/emotion_classifier/weights/best.pt'),
    ]
    
    for path in possible_paths:
        if path.exists():
            print(f"\n✓ Found trained model: {path.absolute()}")
            return str(path)
    
    return None


print("✓ TwoStageEmotionDetector class defined!")
# Out:
# ✓ TwoStageEmotionDetector class defined!

# %% [markdown]
# ## 3. Check for Existing Model

# %%
print("="*60)
print("TWO-STAGE EMOTION DETECTION SYSTEM")
print("="*60 + "\n")

trained_model_path = check_trained_model()

if trained_model_path:
    print("\n" + "="*60)
    print("TRAINED MODEL FOUND - SKIPPING TRAINING")
    print("="*60)
    print(f"\nUsing existing model: {trained_model_path}")
    print("\nTo retrain, delete or rename the model file:")
    print("  - best_emotion_model.pt")
    print("  - emotion_runs/emotion_classifier/weights/best.pt\n")
else:
    print("\n" + "="*60)
    print("NO TRAINED MODEL FOUND")
    print("="*60)
    print("\nYou will need to train a model first (see next section)")
# Out:
# ============================================================
# TWO-STAGE EMOTION DETECTION SYSTEM
# ============================================================
#
#
# ============================================================
# NO TRAINED MODEL FOUND
# ============================================================
#
# You will need to train a model first (see next section)

# %% [markdown]
# ## 4. Training (Run only if no model exists)
#
# **Note:** Skip this section if you already have a trained model!

# %%
# Initialize detector for training
detector_train = TwoStageEmotionDetector(
    face_model='yolov8n-face.pt',
    device='cuda'
)

# Configure your dataset path
dataset_path = "data"

# Check if dataset exists
if not Path(dataset_path).exists():
    print(f"\n⚠ Error: Dataset directory not found: {dataset_path}")
    print("Please create dataset with structure:")
    print("  data/")
    print("    train/")
    print("      angry/")
    print("      happy/")
    print("      ...")
    print("    test/")
    print("      angry/")
    print("      happy/")
    print("      ...")
else:
    # Train the emotion classifier
    results = detector_train.train_emotion_classifier(
        dataset_path,
        epochs=20,
        batch=64,
        imgsz=224,
        patience=15
    )
    
    # Validate trained model
    detector_train.validate_emotion_classifier(dataset_path)
    
    # Export model
    print("\n" + "="*60)
    print("EXPORTING MODEL")
    print("="*60 + "\n")
    detector_train.export_emotion_model(format='onnx')
    
    print("\n" + "="*60)
    print("TRAINING COMPLETE!")
    print("="*60)
    print("\nModel saved to root directory:")
    print("  - best_emotion_model.pt")
    print("  - best_emotion_model.onnx\n")
# Out:
# Using device: cuda
# Loading face detection model...
# ✓ Face detector loaded: yolov8n-face.pt
# ✓ Emotion classifier initialized for training
#
# ============================================================
# Training Emotion Classifier
# ============================================================
#
# New https://pypi.org/project/ultralytics/8.3.240 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.232  Python-3.13.7 torch-2.9.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=64, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=emotion_classifier, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=emotion_runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\train... found 28709 images in 7 classes
# val: None...
# test: C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\test... found 7178 images in 7 classes
# Overriding model.yaml nc=1000 with nc=7
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    339207  ultralytics.nn.modules.head.Classify         [256, 7]
# YOLOv8n-cls summary: 56 layers, 1,447,255 parameters, 1,447,255 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 12.92.9 MB/s, size: 1.7 KB)
# train: Scanning C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\train... 28709 images, 0 corrupt: 100% ━━━━━━━━━━━━ 28709/28709 34.1Mit/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 11.64.0 MB/s, size: 1.8 KB)
# val: Scanning C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\test... 7178 images, 0 corrupt: 100% ━━━━━━━━━━━━ 7178/7178 4.3Mit/s 0.0s0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000909, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/20     0.709G      1.602         37        224: 100% ━━━━━━━━━━━━ 449/449 10.3it/s 43.8s0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 16.8it/s 3.4s.4ss
#                    all      0.537      0.975
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/20      0.83G      1.235         37        224: 100% ━━━━━━━━━━━━ 449/449 11.3it/s 39.9s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 18.5it/s 3.1s0.1s
#                    all      0.591      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/20      0.83G      1.147         37        224: 100% ━━━━━━━━━━━━ 449/449 11.3it/s 39.8s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.7it/s 2.9s0.1s
#                    all       0.59      0.987
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/20     0.838G        1.1         37        224: 100% ━━━━━━━━━━━━ 449/449 11.2it/s 40.2s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.2it/s 3.0s.2ss
#                    all      0.621      0.987
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/20      0.84G      1.048         37        224: 100% ━━━━━━━━━━━━ 449/449 11.3it/s 39.7s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 17.9it/s 3.2s.1ss
#                    all      0.634      0.988
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/20      0.84G      1.012         37        224: 100% ━━━━━━━━━━━━ 449/449 11.5it/s 39.0s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 18.1it/s 3.2s.2ss
#                    all      0.644      0.989
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/20      0.84G     0.9842         37        224: 100% ━━━━━━━━━━━━ 449/449 11.5it/s 38.9s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 17.3it/s 3.3s.1ss
#                    all      0.642      0.989
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/20      0.84G     0.9552         37        224: 100% ━━━━━━━━━━━━ 449/449 11.5it/s 38.9s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 17.8it/s 3.2s0.1s
#                    all      0.648      0.991
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/20      0.84G     0.9375         37        224: 100% ━━━━━━━━━━━━ 449/449 11.3it/s 39.8s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 17.2it/s 3.3s0.1s
#                    all      0.652       0.99
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/20     0.846G     0.9066         37        224: 100% ━━━━━━━━━━━━ 449/449 11.5it/s 38.9s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 18.2it/s 3.1s0.2s
#                    all      0.664      0.989
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/20     0.848G     0.8856         37        224: 100% ━━━━━━━━━━━━ 449/449 11.7it/s 38.5s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 17.2it/s 3.3s.2ss
#                    all       0.67      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/20     0.848G     0.8627         37        224: 100% ━━━━━━━━━━━━ 449/449 11.5it/s 39.2s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 18.4it/s 3.1s.2ss
#                    all      0.673      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/20     0.848G     0.8484         37        224: 100% ━━━━━━━━━━━━ 449/449 11.6it/s 38.6s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 17.6it/s 3.2s.1ss
#                    all      0.682      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/20     0.848G     0.8206         37        224: 100% ━━━━━━━━━━━━ 449/449 11.5it/s 38.9s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 18.4it/s 3.1s.2ss
#                    all       0.68      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/20     0.848G     0.8015         37        224: 100% ━━━━━━━━━━━━ 449/449 12.0it/s 37.3s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.3it/s 3.0s0.2s
#                    all      0.683      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/20     0.848G     0.7834         37        224: 100% ━━━━━━━━━━━━ 449/449 11.9it/s 37.7s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.1it/s 3.0s0.1s
#                    all      0.688      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/20     0.848G     0.7572         37        224: 100% ━━━━━━━━━━━━ 449/449 11.6it/s 38.7s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 18.5it/s 3.1s0.1s
#                    all      0.683      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/20     0.848G     0.7405         37        224: 100% ━━━━━━━━━━━━ 449/449 11.5it/s 39.1s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 18.5it/s 3.1s.1ss
#                    all      0.686      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/20     0.848G     0.7246         37        224: 100% ━━━━━━━━━━━━ 449/449 11.6it/s 38.6s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 18.5it/s 3.1s.2ss
#                    all      0.685      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/20     0.848G      0.708         37        224: 100% ━━━━━━━━━━━━ 449/449 11.5it/s 39.0s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 18.5it/s 3.1s.2ss
#                    all       0.69      0.991
#
# 20 epochs completed in 0.253 hours.
# Optimizer stripped from C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier\weights\last.pt, 3.0MB
# Optimizer stripped from C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier\weights\best.pt, 3.0MB
#
# Validating C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier\weights\best.pt...
# Ultralytics 8.3.232  Python-3.13.7 torch-2.9.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,443,847 parameters, 0 gradients, 3.3 GFLOPs
# WARNING Dataset 'split=val' not found, using 'split=test' instead.
# train: C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\train... found 28709 images in 7 classes
# val: C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\test... found 7178 images in 7 classes
# test: C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\test... found 7178 images in 7 classes
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 17.3it/s 3.3s.1ss
#                    all      0.691      0.991
# Speed: 0.1ms preprocess, 0.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier
#
# ✓ Training completed!
# ✓ Best model automatically saved to: c:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\best_emotion_model.pt
#
# Validating emotion classifier...
# Ultralytics 8.3.232  Python-3.13.7 torch-2.9.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,443,847 parameters, 0 gradients, 3.3 GFLOPs
# WARNING Dataset 'split=val' not found, using 'split=test' instead.
# train: C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\train... found 28709 images in 7 classes
# val: C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\test... found 7178 images in 7 classes
# test: C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\test... found 7178 images in 7 classes
# val: Fast image access  (ping: 0.00.0 ms, read: 12.35.0 MB/s, size: 1.8 KB)
# val: Scanning C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\test... 7178 images, 0 corrupt: 100% ━━━━━━━━━━━━ 7178/7178 4.5Mit/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 449/449 74.4it/s 6.0s0.1s
#                    all       0.69      0.991
# Speed: 0.1ms preprocess, 0.7ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\runs\classify\val20
#
# ============================================================
# EXPORTING MODEL
# ============================================================
#
# Exporting emotion classifier to onnx...
# Ultralytics 8.3.232  Python-3.13.7 torch-2.9.1+cu130 CPU (AMD Ryzen 7 7435HS)
#
# PyTorch: starting from 'C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier\weights\best.pt' with input shape (1, 3, 224, 224) BCHW and output shape(s) (1, 7) (2.8 MB)
#
# ONNX: starting export with onnx 1.19.1 opset 22...
# ONNX: slimming with onnxslim 0.1.80...
# ONNX: export success  2.4s, saved as 'C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier\weights\best.onnx' (5.5 MB)
#
# Export complete (2.6s)
# Results saved to C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier\weights
# Predict:         yolo predict task=classify model=C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier\weights\best.onnx imgsz=224
# Validate:        yolo val task=classify model=C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier\weights\best.onnx imgsz=224 data=data
# Visualize:       https://netron.app
# ✓ ONNX model saved to: c:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\best_emotion_model.onnx
# ✓ Export completed!
#
# ============================================================
# TRAINING COMPLETE!
# ============================================================
#
# Model saved to root directory:
#   - best_emotion_model.pt
#   - best_emotion_model.onnx

# %% [markdown]
# ## 5. Load Model for Inference

# %%
# Get the trained model path
model_path = check_trained_model()

if model_path is None:
    print("⚠ No trained model found! Please train a model first (Section 4)")
else:
    # Load trained models for inference
    detector = TwoStageEmotionDetector(
        face_model='yolov8n-face.pt',
        emotion_model=model_path,
        device='cuda'
    )
    
    print("\n" + "="*60)
    print("READY FOR INFERENCE!")
    print("="*60 + "\n")
# Out:
# ✓ Found trained model: c:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\best_emotion_model.pt
# Using device: cuda
# Loading face detection model...
# ✓ Face detector loaded: yolov8n-face.pt
# ✓ Emotion classifier loaded: best_emotion_model.pt
#
# ============================================================
# READY FOR INFERENCE!
# ============================================================

# %% [markdown]
# ## 8. Real-time Webcam Detection

# %%
# Real-time webcam detection
# Press 'q' to quit

detector.process_video(
    'webcam',
    conf_face=0.5,
    conf_emotion=0.3
)
# Out:
# Processing video... Press 'q' to quit
#
# Detected 1 face(s):
#   Face 1: neutral (65.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.94%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.94%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.60%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.66%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.58%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.09%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.24%)
#
# Detected 1 face(s):
#   Face 1: sad (36.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.52%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.18%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.00%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.42%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.18%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.09%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.58%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.87%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.95%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.95%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (30.74%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.83%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.26%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.38%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (29.84%)
#
# Detected 1 face(s):
#   Face 1: sad (29.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.24%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.79%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (27.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (31.56%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.09%)
#
# Detected 1 face(s):
#   Face 1: neutral (30.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.62%)
#
# Detected 1 face(s):
#   Face 1: sad (40.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.42%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.09%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.58%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.81%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.79%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.56%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.82%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.02%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.82%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.18%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.24%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.63%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.58%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.16%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.16%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.63%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.02%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.98%)
#
# Detected 1 face(s):
#   Face 1: neutral (30.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.92%)
#
# Detected 1 face(s):
#   Face 1: angry (35.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.91%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.16%)
#
# Detected 1 face(s):
#   Face 1: angry (35.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.36%)
#
# Detected 1 face(s):
#   Face 1: angry (31.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.26%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.20%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.00%)
#
# Detected 1 face(s):
#   Face 1: angry (33.41%)
#
# Detected 1 face(s):
#   Face 1: sad (32.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.00%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.14%)
#
# Detected 1 face(s):
#   Face 1: angry (34.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (34.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.64%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.02%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.74%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.94%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.16%)
#
# Detected 1 face(s):
#   Face 1: angry (39.63%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.63%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.63%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.98%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.26%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.24%)
#
# Detected 1 face(s):
#   Face 1: angry (41.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.07%)
#
# Detected 1 face(s):
#   Face 1: angry (32.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.40%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.18%)
#
# Detected 1 face(s):
#   Face 1: angry (33.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (34.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (34.69%)
#
# Detected 1 face(s):
#   Face 1: neutral (31.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.51%)
#
# Detected 1 face(s):
#   Face 1: angry (45.73%)
#
# Detected 1 face(s):
#   Face 1: angry (36.13%)
#
# Detected 1 face(s):
#   Face 1: angry (38.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.81%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.69%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.64%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.16%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.66%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.42%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.42%)
#
# Detected 1 face(s):
#   Face 1: neutral (33.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.79%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.58%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.42%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.02%)
#
# Detected 1 face(s):
#   Face 1: angry (31.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.69%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (32.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.24%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.91%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.94%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.69%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.18%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.88%)
#
# Detected 1 face(s):
#   Face 1: angry (34.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (31.74%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.34%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.82%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.00%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.82%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.77%)
#
# Detected 1 face(s):
#   Face 1: angry (44.42%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (33.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (31.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.82%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.97%)
#
# Detected 1 face(s):
#   Face 1: angry (32.59%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (28.98%)
#
# Detected 1 face(s):
#   Face 1: neutral (33.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.42%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.69%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.02%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.69%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.66%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (32.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.34%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.66%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.09%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.69%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.69%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (33.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.24%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.60%)
#
# Detected 1 face(s):
#   Face 1: neutral (31.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.41%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.52%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.79%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.98%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.18%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.91%)
#
# Detected 1 face(s):
#   Face 1: angry (34.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.63%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.10%)
#
# Detected 1 face(s):
#   Face 1: sad (39.87%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.02%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.81%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.52%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (34.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.58%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.34%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.89%)
#
# Detected 1 face(s):
#   Face 1: sad (37.08%)
#
# Detected 1 face(s):
#   Face 1: angry (38.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.00%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.87%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.95%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.63%)
#
# Detected 1 face(s):
#   Face 1: sad (37.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.18%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.79%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.02%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.59%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.85%)
#
# Detected 1 face(s):
#   Face 1: angry (35.58%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.98%)
#
# Detected 1 face(s):
#   Face 1: angry (40.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.02%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (32.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.16%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.58%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.56%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.52%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.98%)
#
# Detected 1 face(s):
#   Face 1: neutral (34.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.91%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.20%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.60%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.60%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.66%)
#
# Detected 1 face(s):
#   Face 1: surprised (33.52%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.34%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.34%)
#
# Detected 1 face(s):
#   Face 1: neutral (29.16%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.60%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.34%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.24%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.09%)
#
# Detected 1 face(s):
#   Face 1: angry (40.25%)
#
# Detected 1 face(s):
#   Face 1: angry (31.52%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.09%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.42%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.58%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.58%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (34.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.74%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.18%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.65%)
#
# Detected 1 face(s):
#   Face 1: sad (31.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.59%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.41%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.41%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.91%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.91%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.63%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.09%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.02%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.58%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.98%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.27%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.59%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.26%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.63%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.82%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.02%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.24%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.52%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.40%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.98%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.42%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.68%)
#
# Detected 1 face(s):
#   Face 1: angry (34.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.60%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.27%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.56%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.00%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.38%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.91%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.55%)
#
# Detected 1 face(s):
#   Face 1: angry (65.33%)
#
# Detected 1 face(s):
#   Face 1: angry (37.49%)
#
# Detected 1 face(s):
#   Face 1: angry (55.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.70%)
#
# Detected 1 face(s):
#   Face 1: angry (38.81%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.45%)
#
# Detected 1 face(s):
#   Face 1: angry (33.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (87.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.83%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.79%)
#
# Detected 1 face(s):
#   Face 1: neutral (86.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (70.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.95%)
#
# Detected 1 face(s):
#   Face 1: neutral (86.63%)
#
# Detected 1 face(s):
#   Face 1: neutral (88.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.34%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.34%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.87%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.60%)
#
# Detected 1 face(s):
#   Face 1: neutral (70.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.40%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.81%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (89.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (86.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.74%)
#
# Detected 1 face(s):
#   Face 1: neutral (70.91%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.50%)
#
# Detected 1 face(s):
#   Face 1: happy (50.16%)
#
# Detected 1 face(s):
#   Face 1: happy (64.43%)
#
# Detected 1 face(s):
#   Face 1: happy (58.58%)
#
# Detected 1 face(s):
#   Face 1: happy (65.46%)
#
# Detected 1 face(s):
#   Face 1: happy (63.93%)
#
# Detected 1 face(s):
#   Face 1: happy (65.79%)
#
# Detected 1 face(s):
#   Face 1: happy (70.81%)
#
# Detected 1 face(s):
#   Face 1: happy (61.02%)
#
# Detected 1 face(s):
#   Face 1: happy (71.78%)
#
# Detected 1 face(s):
#   Face 1: happy (68.90%)
#
# Detected 1 face(s):
#   Face 1: happy (65.34%)
#
# Detected 1 face(s):
#   Face 1: happy (65.34%)
#
# Detected 1 face(s):
#   Face 1: happy (68.48%)
#
# Detected 1 face(s):
#   Face 1: happy (72.40%)
#
# Detected 1 face(s):
#   Face 1: happy (71.66%)
#
# Detected 1 face(s):
#   Face 1: happy (72.22%)
#
# Detected 1 face(s):
#   Face 1: happy (66.00%)
#
# Detected 1 face(s):
#   Face 1: happy (64.54%)
#
# Detected 1 face(s):
#   Face 1: happy (68.99%)
#
# Detected 1 face(s):
#   Face 1: happy (63.80%)
#
# Detected 1 face(s):
#   Face 1: happy (56.82%)
#
# Detected 1 face(s):
#   Face 1: happy (62.94%)
#
# Detected 1 face(s):
#   Face 1: happy (62.47%)
#
# Detected 1 face(s):
#   Face 1: happy (60.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (86.79%)
#
# Detected 1 face(s):
#   Face 1: neutral (81.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (81.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (70.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.63%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.66%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.82%)
#
# Detected 1 face(s):
#   Face 1: sad (42.03%)
#
# Detected 1 face(s):
#   Face 1: fearful (30.32%)
#
# Detected 1 face(s):
#   Face 1: fearful (29.88%)
#
# Detected 1 face(s):
#   Face 1: disgusted (28.11%)
#
# Detected 1 face(s):
#   Face 1: angry (27.69%)
#
# Detected 1 face(s):
#   Face 1: disgusted (27.19%)
#
# Detected 1 face(s):
#   Face 1: angry (27.82%)
#
# Detected 1 face(s):
#   Face 1: disgusted (26.42%)
#
# Detected 1 face(s):
#   Face 1: fearful (34.03%)
#
# Detected 1 face(s):
#   Face 1: fearful (36.95%)
#
# Detected 1 face(s):
#   Face 1: fearful (40.79%)
#
# Detected 1 face(s):
#   Face 1: fearful (38.56%)
#
# Detected 1 face(s):
#   Face 1: fearful (38.05%)
#
# Detected 1 face(s):
#   Face 1: fearful (40.58%)
#
# Detected 1 face(s):
#   Face 1: fearful (43.57%)
#
# Detected 1 face(s):
#   Face 1: fearful (49.48%)
#
# Detected 1 face(s):
#   Face 1: fearful (36.37%)
#
# Detected 1 face(s):
#   Face 1: fearful (44.10%)
#
# Detected 1 face(s):
#   Face 1: fearful (38.26%)
#
# Detected 1 face(s):
#   Face 1: fearful (43.95%)
#
# Detected 1 face(s):
#   Face 1: fearful (43.83%)
#
# Detected 1 face(s):
#   Face 1: fearful (48.21%)
#
# Detected 1 face(s):
#   Face 1: fearful (41.64%)
#
# Detected 1 face(s):
#   Face 1: fearful (38.16%)
#
# Detected 1 face(s):
#   Face 1: fearful (36.00%)
#
# Detected 1 face(s):
#   Face 1: fearful (40.47%)
#
# Detected 1 face(s):
#   Face 1: fearful (40.47%)
#
# Detected 1 face(s):
#   Face 1: fearful (34.75%)
#
# Detected 1 face(s):
#   Face 1: fearful (35.67%)
#
# Detected 1 face(s):
#   Face 1: fearful (48.77%)
#
# Detected 1 face(s):
#   Face 1: fearful (34.29%)
#
# Detected 1 face(s):
#   Face 1: fearful (36.29%)
#
# Detected 1 face(s):
#   Face 1: fearful (38.22%)
#
# Detected 1 face(s):
#   Face 1: fearful (35.73%)
#
# Detected 1 face(s):
#   Face 1: fearful (40.49%)
#
# Detected 1 face(s):
#   Face 1: fearful (29.93%)
#
# Detected 1 face(s):
#   Face 1: fearful (32.63%)
#
# Detected 1 face(s):
#   Face 1: fearful (34.85%)
#
# Detected 1 face(s):
#   Face 1: fearful (33.19%)
#
# Detected 1 face(s):
#   Face 1: fearful (41.48%)
#
# Detected 1 face(s):
#   Face 1: fearful (34.20%)
#
# Detected 1 face(s):
#   Face 1: fearful (33.97%)
#
# Detected 1 face(s):
#   Face 1: fearful (27.91%)
#
# Detected 1 face(s):
#   Face 1: fearful (29.53%)
#
# Detected 1 face(s):
#   Face 1: fearful (26.05%)
#
# Detected 1 face(s):
#   Face 1: sad (28.26%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (70.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.52%)
#
# Detected 1 face(s):
#   Face 1: neutral (89.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (87.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (87.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.42%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.94%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.91%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.60%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.52%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (88.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (89.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (81.58%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.81%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.74%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.66%)
#
# Detected 1 face(s):
#   Face 1: sad (39.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (74.59%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.09%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.52%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.03%)
#
# Detected 1 face(s):
#   Face 1: sad (48.49%)
#
# Detected 1 face(s):
#   Face 1: sad (48.58%)
#
# Detected 1 face(s):
#   Face 1: sad (43.27%)
#
# Detected 1 face(s):
#   Face 1: sad (44.12%)
#
# Detected 1 face(s):
#   Face 1: sad (46.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.95%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.99%)
#
# Detected 1 face(s):
#   Face 1: sad (52.05%)
#
# Detected 1 face(s):
#   Face 1: sad (58.04%)
#
# Detected 1 face(s):
#   Face 1: sad (49.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.48%)
#
# Detected 1 face(s):
#   Face 1: sad (52.38%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.02%)
#
# Detected 1 face(s):
#   Face 1: sad (50.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.66%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.79%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.16%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.18%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (88.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (87.34%)
#
# Detected 1 face(s):
#   Face 1: neutral (90.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (87.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (87.41%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.95%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.16%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.16%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.91%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.20%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.16%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.74%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.83%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.00%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (29.59%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.57%)
#
# Detected 1 face(s):
#   Face 1: surprised (32.86%)
#
# Detected 1 face(s):
# ...
#
# Detected 1 face(s):
#   Face 1: neutral (51.09%)
#
# Detected 1 face(s):
#   Face 1: happy (54.85%)
#
# Detected 1 face(s):
#   Face 1: happy (73.91%)
#
# Detected 1 face(s):
#   Face 1: happy (80.42%)
#
# Detected 1 face(s):
#   Face 1: happy (76.99%)
#
# Detected 1 face(s):
#   Face 1: happy (70.49%)
#
# Detected 1 face(s):
#   Face 1: happy (87.29%)
#
# Detected 1 face(s):
#   Face 1: happy (82.70%)
#
# Detected 1 face(s):
#   Face 1: happy (82.32%)
#
# Detected 1 face(s):
#   Face 1: happy (80.35%)
#
# Detected 1 face(s):
#   Face 1: happy (79.02%)
#
# Detected 1 face(s):
#   Face 1: happy (81.78%)
#
# Detected 1 face(s):
#   Face 1: happy (77.14%)
#
# Detected 1 face(s):
#   Face 1: happy (83.98%)
#
# Detected 1 face(s):
#   Face 1: happy (89.72%)
#
# Detected 1 face(s):
#   Face 1: happy (85.40%)
#
# Detected 1 face(s):
#   Face 1: happy (82.38%)
#
# Detected 1 face(s):
#   Face 1: happy (83.60%)
#
# Detected 1 face(s):
#   Face 1: happy (78.21%)
#
# Detected 1 face(s):
#   Face 1: happy (74.49%)
#
# Detected 1 face(s):
#   Face 1: happy (83.43%)
#
# Detected 1 face(s):
#   Face 1: happy (80.79%)
#
# Detected 1 face(s):
#   Face 1: happy (76.67%)
#
# Detected 1 face(s):
#   Face 1: happy (82.57%)
#
# Detected 1 face(s):
#   Face 1: happy (82.16%)
#
# Detected 1 face(s):
#   Face 1: happy (84.81%)
#
# Detected 1 face(s):
#   Face 1: happy (83.48%)
#
# Detected 1 face(s):
#   Face 1: happy (74.88%)
#
# Detected 1 face(s):
#   Face 1: happy (69.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.56%)
#
# Detected 1 face(s):
#   Face 1: neutral (86.02%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.00%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.87%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.42%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.41%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.95%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.26%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.66%)
#
# Detected 1 face(s):
#   Face 1: neutral (31.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (30.52%)
#
# Detected 1 face(s):
#   Face 1: fearful (32.64%)
#
# Detected 1 face(s):
#   Face 1: fearful (32.64%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (32.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.66%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.41%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (32.94%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.02%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (34.26%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (34.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (33.15%)
#
# Detected 1 face(s):
#   Face 1: sad (33.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.47%)
#
# Detected 1 face(s):
#   Face 1: sad (32.20%)
#
# Detected 1 face(s):
#   Face 1: sad (32.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.26%)
#
# Detected 1 face(s):
#   Face 1: neutral (34.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.87%)
#
# Detected 1 face(s):
#   Face 1: neutral (30.41%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.40%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.87%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.94%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.38%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.82%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.18%)
#
# Detected 1 face(s):
#   Face 1: sad (35.59%)
#
# Detected 1 face(s):
#   Face 1: sad (38.81%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.98%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.02%)
#
# Detected 1 face(s):
#   Face 1: sad (34.52%)
#
# Detected 1 face(s):
#   Face 1: sad (34.44%)
#
# Detected 1 face(s):
#   Face 1: sad (40.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.50%)
#
# Detected 1 face(s):
#   Face 1: sad (33.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.48%)
#
# Detected 1 face(s):
#   Face 1: sad (37.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.37%)
#
# Detected 1 face(s):
#   Face 1: sad (38.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.18%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.76%)
#
# Detected 1 face(s):
#   Face 1: sad (37.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (33.64%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.81%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.64%)
#
# Detected 1 face(s):
#   Face 1: neutral (74.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.27%)
#
# Detected 1 face(s):
#   Face 1: neutral (70.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.26%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (29.83%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.42%)
#
# Detected 1 face(s):
#   Face 1: neutral (26.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (34.25%)
#
# Detected 1 face(s):
#   Face 1: angry (29.92%)
#
# Detected 1 face(s):
#   Face 1: disgusted (23.84%)
#
# Detected 1 face(s):
#   Face 1: angry (26.77%)
#
# Detected 1 face(s):
#   Face 1: angry (35.40%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (32.20%)
#
# Detected 1 face(s):
#   Face 1: neutral (28.67%)
#
# Detected 1 face(s):
#   Face 1: angry (36.26%)
#
# Detected 1 face(s):
#   Face 1: angry (37.55%)
#
# Detected 1 face(s):
#   Face 1: angry (33.60%)
#
# Detected 1 face(s):
#   Face 1: angry (30.12%)
#
# Detected 1 face(s):
#   Face 1: angry (38.63%)
#
# Detected 1 face(s):
#   Face 1: angry (43.99%)
#
# Detected 1 face(s):
#   Face 1: angry (42.41%)
#
# Detected 1 face(s):
#   Face 1: angry (52.86%)
#
# Detected 1 face(s):
#   Face 1: angry (33.69%)
#
# Detected 1 face(s):
#   Face 1: angry (34.08%)
#
# Detected 1 face(s):
#   Face 1: angry (30.91%)
#
# Detected 1 face(s):
#   Face 1: angry (42.02%)
#
# Detected 1 face(s):
#   Face 1: angry (33.29%)
#
# Detected 1 face(s):
#   Face 1: angry (29.55%)
#
# Detected 1 face(s):
#   Face 1: angry (38.64%)
#
# Detected 1 face(s):
#   Face 1: angry (25.97%)
#
# Detected 1 face(s):
#   Face 1: angry (35.26%)
#
# Detected 1 face(s):
#   Face 1: angry (35.41%)
#
# Detected 1 face(s):
#   Face 1: angry (41.66%)
#
# Detected 1 face(s):
#   Face 1: sad (25.96%)
#
# Detected 1 face(s):
#   Face 1: sad (25.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.63%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.23%)
#
# Detected 1 face(s):
#   Face 1: happy (66.80%)
#
# Detected 1 face(s):
#   Face 1: happy (64.30%)
#
# Detected 1 face(s):
#   Face 1: happy (77.21%)
#
# Detected 1 face(s):
#   Face 1: happy (76.30%)
#
# Detected 1 face(s):
#   Face 1: happy (76.89%)
#
# Detected 1 face(s):
#   Face 1: happy (81.12%)
#
# Detected 1 face(s):
#   Face 1: happy (81.12%)
#
# Detected 1 face(s):
#   Face 1: happy (81.54%)
#
# Detected 1 face(s):
#   Face 1: happy (82.25%)
#
# Detected 1 face(s):
#   Face 1: happy (85.85%)
#
# Detected 1 face(s):
#   Face 1: happy (76.65%)
#
# Detected 1 face(s):
#   Face 1: happy (72.97%)
#
# Detected 1 face(s):
#   Face 1: happy (76.07%)
#
# Detected 1 face(s):
#   Face 1: happy (69.59%)
#
# Detected 1 face(s):
#   Face 1: happy (74.88%)
#
# Detected 1 face(s):
#   Face 1: happy (52.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.79%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.18%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.81%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.34%)
#
# Detected 1 face(s):
#   Face 1: neutral (74.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (70.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.81%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.24%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.40%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (27.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (25.99%)
#
# Detected 1 face(s):
#   Face 1: disgusted (26.10%)
#
# Detected 1 face(s):
#   Face 1: disgusted (40.71%)
#
# Detected 1 face(s):
#   Face 1: disgusted (40.52%)
#
# Detected 1 face(s):
#   Face 1: disgusted (39.25%)
#
# Detected 1 face(s):
#   Face 1: fearful (38.92%)
#
# Detected 1 face(s):
#   Face 1: disgusted (40.55%)
#
# Detected 1 face(s):
#   Face 1: fearful (29.40%)
#
# Detected 1 face(s):
#   Face 1: disgusted (45.82%)
#
# Detected 1 face(s):
#   Face 1: disgusted (37.67%)
#
# Detected 1 face(s):
#   Face 1: fearful (41.06%)
#
# Detected 1 face(s):
#   Face 1: disgusted (44.58%)
#
# Detected 1 face(s):
#   Face 1: fearful (35.54%)
#
# Detected 1 face(s):
#   Face 1: fearful (35.54%)
#
# Detected 1 face(s):
#   Face 1: fearful (46.60%)
#
# Detected 1 face(s):
#   Face 1: fearful (34.97%)
#
# Detected 1 face(s):
#   Face 1: disgusted (34.02%)
#
# Detected 1 face(s):
#   Face 1: fearful (32.64%)
#
# Detected 1 face(s):
#   Face 1: fearful (33.34%)
#
# Detected 1 face(s):
#   Face 1: disgusted (44.13%)
#
# Detected 1 face(s):
#   Face 1: fearful (34.67%)
#
# Detected 1 face(s):
#   Face 1: fearful (45.81%)
#
# Detected 1 face(s):
#   Face 1: fearful (48.24%)
#
# Detected 1 face(s):
#   Face 1: fearful (40.68%)
#
# Detected 1 face(s):
#   Face 1: fearful (41.51%)
#
# Detected 1 face(s):
#   Face 1: disgusted (35.40%)
#
# Detected 1 face(s):
#   Face 1: disgusted (40.73%)
#
# Detected 1 face(s):
#   Face 1: fearful (33.39%)
#
# Detected 1 face(s):
#   Face 1: disgusted (35.32%)
#
# Detected 1 face(s):
#   Face 1: disgusted (37.28%)
#
# Detected 1 face(s):
#   Face 1: disgusted (33.02%)
#
# Detected 1 face(s):
#   Face 1: disgusted (54.46%)
#
# Detected 1 face(s):
#   Face 1: disgusted (44.40%)
#
# Detected 1 face(s):
#   Face 1: disgusted (34.31%)
#
# Detected 1 face(s):
#   Face 1: fearful (36.15%)
#
# Detected 1 face(s):
#   Face 1: disgusted (37.58%)
#
# Detected 1 face(s):
#   Face 1: fearful (28.48%)
#
# Detected 1 face(s):
#   Face 1: disgusted (53.62%)
#
# Detected 1 face(s):
#   Face 1: disgusted (52.11%)
#
# Detected 1 face(s):
#   Face 1: disgusted (49.53%)
#
# Detected 1 face(s):
#   Face 1: fearful (31.33%)
#
# Detected 1 face(s):
#   Face 1: disgusted (38.72%)
#
# Detected 1 face(s):
#   Face 1: sad (24.23%)
#
# Detected 1 face(s):
#   Face 1: fearful (32.32%)
#
# Detected 1 face(s):
#   Face 1: fearful (33.81%)
#
# Detected 1 face(s):
#   Face 1: neutral (27.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (33.93%)
#
# Detected 1 face(s):
#   Face 1: fearful (33.51%)
#
# Detected 1 face(s):
#   Face 1: fearful (25.55%)
#
# Detected 1 face(s):
#   Face 1: fearful (28.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.82%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.82%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.56%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.66%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.69%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.83%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.79%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.82%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.82%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.82%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.56%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.95%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.24%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.18%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.40%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.00%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.27%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.83%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.50%)
#
# ✓ Video processing completed! Processed 1884 frames

# %% [markdown]
# ## 10. Copy Training Metrics to Root Directory

# %%
# Copy training metrics to root directory for easy access
import shutil
from pathlib import Path

results_path = Path('emotion_runs/emotion_classifier')

if results_path.exists():
    print("Copying training metrics to root directory...\n")
    
    # Files to copy
    files_to_copy = {
        'results.csv': 'training_results.csv'
    }
    
    copied_files = []
    
    for src_name, dst_name in files_to_copy.items():
        src_path = results_path / src_name
        dst_path = Path(dst_name)
        
        if src_path.exists():
            shutil.copy2(src_path, dst_path)
            copied_files.append(dst_name)
            print(f"✓ Copied: {dst_name}")
        else:
            print(f"⚠ Not found: {src_name}")
    
    if copied_files:
        print(f"\n✓ Successfully copied {len(copied_files)} file(s) to root directory!")
        print("\nFiles in root directory:")
        for file in copied_files:
            print(f"  - {file}")
    else:
        print("\n⚠ No files were copied.")
else:
    print("⚠ No training results found. Train a model first (Section 4)!")
# Out:
# Copying training metrics to root directory...
#
# ✓ Copied: training_results.csv
#
# ✓ Successfully copied 1 file(s) to root directory!
#
# Files in root directory:
#   - training_results.csv

# %% [markdown]
# ## 11. Display Training Metrics

# %%
# ===== FULL EVALUATION: TRAINING HISTORY + CONFUSION MATRIX =====

import cv2
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
from pathlib import Path
from sklearn.metrics import confusion_matrix, accuracy_score

# %matplotlib inline
sns.set_theme(style="whitegrid", font_scale=1.1)

# =========================================================
# PART 1 — TRAINING HISTORY (Accuracy & Loss)
# =========================================================

csv_paths = [
    Path("training_results.csv"),
    Path("emotion_runs/emotion_classifier/results.csv")
]

csv_path = next((p for p in csv_paths if p.exists()), None)
if csv_path is None:
    raise FileNotFoundError("❌ results.csv not found. Train model first.")

print(f"✓ Loaded training history: {csv_path}")

df = pd.read_csv(csv_path)
df.columns = df.columns.str.strip()

# -------- Accuracy Plot --------
plt.figure(figsize=(9, 4))
sns.lineplot(
    data=df,
    x="epoch",
    y="metrics/accuracy_top1",
    marker="o"
)
plt.title("Training Accuracy (Top-1)")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.tight_layout()
plt.show()

# -------- Loss Plot --------
plt.figure(figsize=(9, 4))
sns.lineplot(
    data=df,
    x="epoch",
    y="train/loss",
    label="Train Loss"
)

if "val/loss" in df.columns:
    sns.lineplot(
        data=df,
        x="epoch",
        y="val/loss",
        label="Validation Loss"
    )

plt.title("Training Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.tight_layout()
plt.show()

# -------- Best Epoch --------
best_idx = df["metrics/accuracy_top1"].idxmax()
best_epoch = int(df.loc[best_idx, "epoch"])
best_acc = df.loc[best_idx, "metrics/accuracy_top1"]

print("=" * 60)
print(f"✓ Best Training Accuracy : {best_acc:.4f}")
print(f"✓ Best Epoch             : {best_epoch}")
print("=" * 60)


# =========================================================
# PART 2 — CONFUSION MATRIX (TEST SET, NUMERIC)
# =========================================================

DATASET_DIR = Path("data/test")
MODEL = detector.emotion_classifier

class_names = sorted([d.name for d in DATASET_DIR.iterdir() if d.is_dir()])

y_true, y_pred = [], []

print("\nRunning inference on test set...")

for true_idx, class_name in enumerate(class_names):
    for img_path in (DATASET_DIR / class_name).glob("*.*"):
        img = cv2.imread(str(img_path))
        if img is None:
            continue
        
        results = MODEL(img, verbose=False)
        y_pred.append(results[0].probs.top1)
        y_true.append(true_idx)

# -------- Test Accuracy --------
test_acc = accuracy_score(y_true, y_pred)
print(f"\n✅ Test Accuracy: {test_acc:.4f}")

# -------- Confusion Matrix --------
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix (Test Set)")
plt.tight_layout()
plt.show()

# -------- Normalized Confusion Matrix --------
cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm_norm,
    annot=True,
    fmt=".2f",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names
)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Normalized Confusion Matrix (Test Set)")
plt.tight_layout()
plt.show()

# =========================================================
# PART 3 — CLASSIFICATION REPORT & PER-CLASS ACCURACY
# =========================================================

from sklearn.metrics import classification_report

print("\n" + "=" * 60)
print("CLASSIFICATION REPORT (TEST SET)")
print("=" * 60)

report = classification_report(
    y_true,
    y_pred,
    target_names=class_names,
    digits=4
)
print(report)

# -------- Per-class Accuracy --------
per_class_acc = cm.diagonal() / cm.sum(axis=1)

acc_df = pd.DataFrame({
    "Class": class_names,
    "Accuracy": per_class_acc
}).sort_values("Accuracy", ascending=False)

print("\n" + "=" * 60)
print("PER-CLASS ACCURACY")
print("=" * 60)
display(acc_df)

# -------- Per-class Accuracy Plot --------
plt.figure(figsize=(9, 4))
sns.barplot(
    data=acc_df,
    x="Class",
    y="Accuracy"
)
plt.ylim(0, 1)
plt.title("Per-Class Accuracy (Test Set)")
plt.ylabel("Accuracy")
plt.xlabel("Emotion Class")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# =========================================================
# PART 4 — AUTO INTERPRETATION (FOR REPORT)
# =========================================================

best_class = acc_df.iloc[0]
worst_class = acc_df.iloc[-1]

print("\n" + "=" * 60)
print("AUTO INTERPRETATION SUMMARY")
print("=" * 60)

print(f"✓ Overall Test Accuracy      : {test_acc:.4f}")
print(f"✓ Best Classified Emotion    : {best_class['Class']} ({best_class['Accuracy']:.2%})")
print(f"✓ Worst Classified Emotion   : {worst_class['Class']} ({worst_class['Accuracy']:.2%})")

print("\nInterpretation:")
print(
    f"The emotion classification model shows stable generalization performance "
    f"with a test accuracy of {test_acc:.2%}. Certain emotions such as "
    f"'{best_class['Class']}' are classified more accurately, while "
    f"'{worst_class['Class']}' remains more challenging, likely due to class "
    f"imbalance or subtle visual differences between expressions."
)
# Out:
# ✓ Loaded training history: training_results.csv
# ============================================================
# ✓ Best Training Accuracy : 0.6899
# ✓ Best Epoch             : 20
# ============================================================
#
# Running inference on test set...
#
# ✅ Test Accuracy: 0.6897
# ============================================================
# CLASSIFICATION REPORT (TEST SET)
# ============================================================
#               precision    recall  f1-score   support
#
#        angry     0.5943    0.6117    0.6029       958
#    disgusted     0.7356    0.5766    0.6465       111
#      fearful     0.5581    0.4834    0.5181      1024
#        happy     0.8849    0.8923    0.8886      1774
#      neutral     0.6165    0.7015    0.6563      1233
#          sad     0.5776    0.5581    0.5677      1247
#    surprised     0.8063    0.7966    0.8015       831
#
#     accuracy                         0.6897      7178
#    macro avg     0.6819    0.6600    0.6688      7178
# weighted avg     0.6886    0.6897    0.6881      7178
#
#
# ============================================================
# PER-CLASS ACCURACY
# ============================================================
#        Class  Accuracy
# 3      happy  0.892334
# 6  surprised  0.796631
# 4    neutral  0.701541
# 0      angry  0.611691
# 1  disgusted  0.576577
# 5        sad  0.558140
# 2    fearful  0.483398
# ============================================================
# AUTO INTERPRETATION SUMMARY
# ============================================================
# ✓ Overall Test Accuracy      : 0.6897
# ✓ Best Classified Emotion    : happy (89.23%)
# ✓ Worst Classified Emotion   : fearful (48.34%)
#
# Interpretation:
# The emotion classification model shows stable generalization performance with a test accuracy of 68.97%. Certain emotions such as 'happy' are classified more accurately, while 'fearful' remains more challenging, likely due to class imbalance or subtle visual differences between expressions.

# %% [markdown]
# ## 12. View Training Results CSV

# %%
# Display training metrics as a table
import pandas as pd
from pathlib import Path

# Try to find results.csv
csv_paths = [
    Path('training_results.csv'),
    Path('emotion_runs/emotion_classifier/results.csv')
]

csv_path = None
for path in csv_paths:
    if path.exists():
        csv_path = path
        break

if csv_path:
    print("Training Metrics Summary:")
    print("="*60 + "\n")
    
    df = pd.read_csv(csv_path)
    
    # Clean column names (remove extra spaces)
    df.columns = df.columns.str.strip()
    
    # Display first few rows
    print("First 5 epochs:")
    display(df.head())
    
    # Display last few rows
    print("\nLast 5 epochs:")
    display(df.tail())
    
    # Find best epoch
    if 'metrics/accuracy_top1' in df.columns:
        best_idx = df['metrics/accuracy_top1'].idxmax()
        best_acc = df.loc[best_idx, 'metrics/accuracy_top1']
        best_epoch = df.loc[best_idx, 'epoch']
        
        print(f"\n" + "="*60)
        print(f"✓ Best Accuracy: {best_acc:.4f} at Epoch {int(best_epoch)}")
        print("="*60)
else:
    print("⚠ Training results CSV not found!")
    print("Train a model first or copy metrics to root directory.")
# Out:
# Training Metrics Summary:
# ============================================================
#
# First 5 epochs:
#    epoch      time  train/loss  metrics/accuracy_top1  metrics/accuracy_top5  \
# 0      1   47.2923     1.60161                0.53650                0.97478
# 1      2   91.3995     1.23451                0.59055                0.98384
# 2      3  134.5320     1.14684                0.59014                0.98663
# 3      4  178.0900     1.09998                0.62148                0.98663
# 4      5  221.3850     1.04795                0.63444                0.98844
#
#    val/loss    lr/pg0    lr/pg1    lr/pg2
# 0   1.21861  0.000302  0.000302  0.000302
# 1   1.09046  0.000575  0.000575  0.000575
# 2   1.09921  0.000818  0.000818  0.000818
# 3   1.00443  0.000774  0.000774  0.000774
# 4   0.97639  0.000729  0.000729  0.000729
# Last 5 epochs:
#     epoch     time  train/loss  metrics/accuracy_top1  metrics/accuracy_top5  \
# 15     16  740.955     0.78339                0.68780                0.99150
# 16     17  783.075     0.75716                0.68334                0.99192
# 17     18  825.597     0.74048                0.68640                0.99178
# 18     19  867.651     0.72455                0.68515                0.99192
# 19     20  910.066     0.70798                0.68989                0.99108
#
#     val/loss    lr/pg0    lr/pg1    lr/pg2
# 15   0.85732  0.000234  0.000234  0.000234
# 16   0.87425  0.000189  0.000189  0.000189
# 17   0.87953  0.000144  0.000144  0.000144
# 18   0.87158  0.000099  0.000099  0.000099
# 19   0.87435  0.000054  0.000054  0.000054
# ============================================================
# ✓ Best Accuracy: 0.6899 at Epoch 20
# ============================================================
