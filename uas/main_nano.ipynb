# %% [markdown]
# # Two-Stage Emotion Detection System
#
# This notebook implements a two-stage emotion detection system:
# - **Stage 1**: Detect faces using pre-trained YOLO
# - **Stage 2**: Classify emotions from detected face regions
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
import torch
from ultralytics import YOLO
import cv2
import numpy as np
from pathlib import Path
from PIL import Image
import shutil
from IPython.display import display, Image as IPImage, clear_output
import matplotlib.pyplot as plt

print("✓ Libraries imported successfully!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 from ultralytics import YOLO
#       3 import cv2
#
# File c:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\.venv\Lib\site-packages\torch\__init__.py:2680
#    2676 from torch.func import vmap as vmap
#    2679 if not TYPE_CHECKING:
# -> 2680     from torch import _meta_registrations
#    2682 # Enable CUDA Sanitizer
#    2683 if "TORCH_CUDA_SANITIZER" in os.environ:
#
# File c:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\.venv\Lib\site-packages\torch\_meta_registrations.py:12
#      10 import torch._prims_common as utils
#      11 from torch import SymBool, SymFloat, Tensor
# ---> 12 from torch._decomp import (
#      13     _add_op_to_registry,
#      14     _convert_out_params,
#      15     global_decomposition_table,
#      16     meta_table,
#      17 )
#      18 from torch._ops import OpOverload
#      19 from torch._prims import _prim_elementwise_meta, ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND
#
# File c:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\.venv\Lib\site-packages\torch\_decomp\__init__.py:276
#     272             decompositions.pop(op, None)
#     275 # populate the table
# --> 276 import torch._decomp.decompositions
#     277 import torch._refs
#     280 def core_aten_decompositions() -> "CustomDecompTable":
#
# File c:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\.venv\Lib\site-packages\torch\_decomp\decompositions.py:16
#      14 import torch
#      15 import torch._meta_registrations
# ---> 16 import torch._prims as prims
#      17 import torch._prims_common as utils
#      18 import torch.nn.functional as F
#
# File c:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\.venv\Lib\site-packages\torch\_prims\__init__.py:780
#     774     return _prim_elementwise_meta(
#     775         a, type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.DEFAULT
#     776     )
#     779 # NOTE: fill uses _make_prim directly because it has a value parameter
# --> 780 fill = _make_prim(
#     781     schema="fill(Tensor self, Scalar value) -> Tensor",
#     782     return_type=RETURN_TYPE.NEW,
#     783     meta=_fill_meta,
#     784     impl_aten=torch.fill,
#     785     doc="",
#     786 )
#     788 floor = _make_elementwise_unary_prim(
#     789     "floor",
#     790     impl_aten=torch.floor,
#     791     doc="",
#     792     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.DEFAULT,
#     793 )
#     795 imag = _make_prim(
#     796     schema="imag(Tensor(a) self) -> Tensor(a)",
#     797     meta=partial(
#    (...)    803     doc="",
#     804 )
#
# File c:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\.venv\Lib\site-packages\torch\_prims\__init__.py:321, in _make_prim(schema, return_type, meta, impl_aten, doc, tags, use_old_custom_ops_api, register_conj_neg_fallthrough)
#     315 else:
#     316     mutates_args = [
#     317         arg.name
#     318         for arg in cpp_schema.arguments
#     319         if arg.alias_info is not None and arg.alias_info.is_write
#     320     ]
# --> 321     prim_def = torch.library.custom_op(
#     322         "prims::" + name,
#     323         _prim_impl,
#     324         mutates_args=tuple(mutates_args),
#     325         schema=schema,
#     326     )
#     327     prim_def.register_fake(meta)
#     329     # all view ops get conj/neg fallthroughs
#
# File c:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\.venv\Lib\site-packages\torch\_library\custom_ops.py:172, in custom_op(name, fn, mutates_args, device_types, schema, tags)
#     170 if fn is None:
#     171     return inner
# --> 172 return inner(fn)
#
# File c:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\.venv\Lib\site-packages\torch\_library\custom_ops.py:153, in custom_op.<locals>.inner(fn)
#     150     schema_str = schema
#     152 namespace, opname = name.split("::")
# --> 153 result = CustomOpDef(namespace, opname, schema_str, fn, tags)
#     154 if schema is not None:
#     155     # Check that schema's alias annotations match those of `mutates_args`.
#     156     expected = set()
#
# File c:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\.venv\Lib\site-packages\torch\_library\custom_ops.py:210, in CustomOpDef.__init__(self, namespace, name, schema, fn, tags)
#     207 self._autocast_cuda_dtype: Optional[_dtype] = None
#     208 self._autocast_cpu_dtype: Optional[_dtype] = None
# --> 210 self._lib = get_library_allowing_overwrite(self._namespace, self._name)
#     211 self._register_to_dispatcher(self._tags)
#     212 self._disabled_kernel: set = set()
#
# File c:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\.venv\Lib\site-packages\torch\_library\custom_ops.py:911, in get_library_allowing_overwrite(namespace, name)
#     908     OPDEF_TO_LIB[qualname]._destroy()
#     909     del OPDEF_TO_LIB[qualname]
# --> 911 lib = torch.library.Library(namespace, "FRAGMENT")  # noqa: TOR901
#     912 OPDEF_TO_LIB[qualname] = lib
#     913 return lib
#
# File c:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\.venv\Lib\site-packages\torch\library.py:107, in Library.__init__(self, ns, kind, dispatch_key)
#     101 if ns in _reserved_namespaces and (kind == "DEF" or kind == "FRAGMENT"):
#     102     raise ValueError(
#     103         ns,
#     104         " is a reserved namespace. Please try creating a library with another name.",
#     105     )
# --> 107 frame = traceback.extract_stack(limit=2)[0]
#     108 filename, lineno = frame.filename, frame.lineno
#     109 self.m: Optional[Any] = torch._C._dispatch_library(
#     110     kind, ns, dispatch_key, filename, lineno
#     111 )
#
# File C:\Python313\Lib\traceback.py:260, in extract_stack(f, limit)
#     258 if f is None:
#     259     f = sys._getframe().f_back
# --> 260 stack = StackSummary.extract(walk_stack(f), limit=limit)
#     261 stack.reverse()
#     262 return stack
#
# File C:\Python313\Lib\traceback.py:449, in StackSummary.extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     446     for f, lineno in frame_gen:
#     447         yield f, (lineno, None, None, None)
# --> 449 return klass._extract_from_extended_frame_gen(
#     450     extended_frame_gen(), limit=limit, lookup_lines=lookup_lines,
#     451     capture_locals=capture_locals)
#
# File C:\Python313\Lib\traceback.py:495, in StackSummary._extract_from_extended_frame_gen(klass, frame_gen, limit, lookup_lines, capture_locals)
#     487     result.append(
#     488         FrameSummary(filename, lineno, name,
#     489             lookup_line=False, locals=f_locals,
#    (...)    492         )
#     493     )
#     494 for filename in fnames:
# --> 495     linecache.checkcache(filename)
#     497 # If immediate lookup was desired, trigger lookups now.
#     498 if lookup_lines:
#
# File C:\Python313\Lib\linecache.py:94, in checkcache(filename)
#      92     return
#      93 try:
# ---> 94     stat = os.stat(fullname)
#      95 except (OSError, ValueError):
#      96     cache.pop(filename, None)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 2. TwoStageEmotionDetector Class

# %%
class TwoStageEmotionDetector:
    """
    Two-stage emotion detection system:
    Stage 1: Detect faces using pre-trained YOLO
    Stage 2: Classify emotions from detected face regions
    """
    
    def __init__(self, face_model='yolov8n-face.pt', emotion_model=None, device='cuda'):
        """
        Initialize the two-stage detector.
        
        Args:
            face_model: Pre-trained face detection model path
            emotion_model: Trained emotion classifier path (None for training mode)
            device: Computing device ('cuda' or 'cpu')
        """
        self.device = device if torch.cuda.is_available() else 'cpu'
        print(f"Using device: {self.device}")
        
        # Load face detection model
        print("Loading face detection model...")
        try:
            self.face_detector = YOLO(face_model)
            print(f"✓ Face detector loaded: {face_model}")
        except:
            print(f"⚠ {face_model} not found, falling back to yolov8n.pt")
            print("  For better results, download yolov8n-face.pt from:")
            print("  https://github.com/akanametov/yolov8-face")
            self.face_detector = YOLO('yolov8n.pt')
        
        # Load or initialize emotion classifier
        if emotion_model and Path(emotion_model).exists():
            self.emotion_classifier = YOLO(emotion_model)
            print(f"✓ Emotion classifier loaded: {emotion_model}")
        else:
            self.emotion_classifier = YOLO('yolov8n-cls.pt')
            print("✓ Emotion classifier initialized for training")
    
    def train_emotion_classifier(self, dataset_dir, epochs=20, imgsz=224, batch=64, patience=15):
        """
        Train the emotion classification model.
        """
        print(f"\n{'='*60}")
        print("Training Emotion Classifier")
        print(f"{'='*60}\n")
        
        results = self.emotion_classifier.train(
            data=dataset_dir,
            epochs=epochs,
            imgsz=imgsz,
            batch=batch,
            device=self.device,
            patience=patience,
            save=True,
            plots=True,
            project='emotion_runs',
            name='emotion_classifier'
        )
        
        print("\n✓ Training completed!")
        
        # Automatically copy best model to root directory
        best_model_path = Path('emotion_runs/emotion_classifier/weights/best.pt')
        root_model_path = Path('best_emotion_model.pt')
        
        if best_model_path.exists():
            shutil.copy2(best_model_path, root_model_path)
            print(f"✓ Best model automatically saved to: {root_model_path.absolute()}")
        
        return results
    
    def validate_emotion_classifier(self, dataset_dir):
        """Validate the trained emotion classifier."""
        print("\nValidating emotion classifier...")
        return self.emotion_classifier.val(data=dataset_dir)
    
    def detect_and_classify(self, image_path, conf_face=0.5, conf_emotion=0.3, 
                           save_output=False, output_path=None):
        """
        Perform two-stage emotion detection on an image.
        
        Returns:
            annotated_img: Image with bounding boxes and labels
            emotions_detected: List of detected emotions with metadata
        """
        # Load image
        if isinstance(image_path, str):
            img = cv2.imread(image_path)
            if img is None:
                print(f"Error: Could not read image {image_path}")
                return None, []
        else:
            img = image_path
        
        # Stage 1: Detect faces
        face_results = self.face_detector(img, conf=conf_face, verbose=False)
        
        # Check if any faces detected
        if (face_results is None or len(face_results) == 0 or 
            face_results[0].boxes is None or len(face_results[0].boxes) == 0):
            return img, []
        
        # Stage 2: Classify emotion for each detected face
        emotions_detected = []
        annotated_img = img.copy()
        
        for box in face_results[0].boxes:
            # Extract face region
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            face_crop = img[y1:y2, x1:x2]
            
            if face_crop.size == 0:
                continue
            
            # Classify emotion
            emotion_results = self.emotion_classifier(face_crop, conf=conf_emotion, verbose=False)
            
            if len(emotion_results) > 0:
                probs = emotion_results[0].probs
                top_class = probs.top1
                confidence = probs.top1conf.item()
                emotion = emotion_results[0].names[top_class]
                
                emotions_detected.append({
                    'emotion': emotion,
                    'confidence': confidence,
                    'bbox': [x1, y1, x2, y2]
                })
                
                # Annotate image
                color = self._get_emotion_color(emotion)
                cv2.rectangle(annotated_img, (x1, y1), (x2, y2), color, 2)
                
                # Draw label with background
                label = f"{emotion}: {confidence:.2%}"
                (label_w, label_h), _ = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.6, 2)
                cv2.rectangle(annotated_img, (x1, y1 - label_h - 10), (x1 + label_w, y1), color, -1)
                cv2.putText(annotated_img, label, (x1, y1 - 5),
                           cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)
        
        # Print results
        print(f"\nDetected {len(emotions_detected)} face(s):")
        for i, result in enumerate(emotions_detected, 1):
            print(f"  Face {i}: {result['emotion']} ({result['confidence']:.2%})")
        
        # Save output if requested
        if save_output and output_path:
            cv2.imwrite(output_path, annotated_img)
            print(f"\n✓ Saved annotated image to: {output_path}")
        
        return annotated_img, emotions_detected
    
    def process_video(self, video_source, output_path=None, conf_face=0.5, conf_emotion=0.3):
        """
        Process video file or webcam stream for emotion detection.
        """
        # Open video source
        if video_source == 'webcam':
            video_source = 0
        
        cap = cv2.VideoCapture(video_source)
        
        if not cap.isOpened():
            print(f"Error: Could not open video source {video_source}")
            return
        
        # Setup video writer if output requested
        if output_path:
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            fps = int(cap.get(cv2.CAP_PROP_FPS)) or 30
            width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
        
        print("\nProcessing video... Press 'q' to quit")
        frame_count = 0
        
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break
            
            frame_count += 1
            
            # Process frame
            annotated_frame, emotions = self.detect_and_classify(
                frame, conf_face=conf_face, conf_emotion=conf_emotion
            )
            
            # Always use the frame (annotated or original)
            display_frame = annotated_frame if annotated_frame is not None else frame
            
            # Add frame info overlay
            info_text = f"Frame: {frame_count} | Faces: {len(emotions) if emotions else 0}"
            cv2.putText(display_frame, info_text, (10, 30),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
            
            # Display frame
            cv2.imshow('Emotion Detection', display_frame)
            
            # Save frame if recording
            if output_path:
                out.write(display_frame)
            
            # Check for quit command (MUST be after imshow)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        
        # Cleanup
        cap.release()
        if output_path:
            out.release()
        cv2.destroyAllWindows()
        print(f"\n✓ Video processing completed! Processed {frame_count} frames")
    
    def _get_emotion_color(self, emotion):
        """Map emotions to BGR colors for visualization."""
        colors = {
            'angry': (0, 0, 255),        # Red
            'disgusted': (0, 128, 128),  # Teal
            'fearful': (128, 0, 128),    # Purple
            'happy': (0, 255, 0),        # Green
            'neutral': (128, 128, 128),  # Gray
            'sad': (255, 0, 0),          # Blue
            'surprised': (0, 255, 255),  # Yellow
            'nothing': (200, 200, 200)   # Light gray
        }
        return colors.get(emotion.lower(), (255, 255, 255))
    
    def export_emotion_model(self, format='onnx'):
        """Export emotion classifier to different formats."""
        print(f"Exporting emotion classifier to {format}...")
        self.emotion_classifier.export(format=format)
        
        # Copy exported model to root directory
        if format == 'onnx':
            onnx_path = Path('emotion_runs/emotion_classifier/weights/best.onnx')
            root_onnx_path = Path('best_emotion_model.onnx')
            if onnx_path.exists():
                shutil.copy2(onnx_path, root_onnx_path)
                print(f"✓ ONNX model saved to: {root_onnx_path.absolute()}")
        
        print("✓ Export completed!")


def check_trained_model():
    """Check if a trained emotion model already exists."""
    possible_paths = [
        Path('best_emotion_model.pt'),
        Path('emotion_runs/emotion_classifier/weights/best.pt'),
    ]
    
    for path in possible_paths:
        if path.exists():
            print(f"\n✓ Found trained model: {path.absolute()}")
            return str(path)
    
    return None


print("✓ TwoStageEmotionDetector class defined!")
# Out:
# ✓ TwoStageEmotionDetector class defined!

# %% [markdown]
# ## 3. Check for Existing Model

# %%
print("="*60)
print("TWO-STAGE EMOTION DETECTION SYSTEM")
print("="*60 + "\n")

trained_model_path = check_trained_model()

if trained_model_path:
    print("\n" + "="*60)
    print("TRAINED MODEL FOUND - SKIPPING TRAINING")
    print("="*60)
    print(f"\nUsing existing model: {trained_model_path}")
    print("\nTo retrain, delete or rename the model file:")
    print("  - best_emotion_model.pt")
    print("  - emotion_runs/emotion_classifier/weights/best.pt\n")
else:
    print("\n" + "="*60)
    print("NO TRAINED MODEL FOUND")
    print("="*60)
    print("\nYou will need to train a model first (see next section)")
# Out:
# ============================================================
# TWO-STAGE EMOTION DETECTION SYSTEM
# ============================================================
#
#
# ✓ Found trained model: c:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\best_emotion_model.pt
#
# ============================================================
# TRAINED MODEL FOUND - SKIPPING TRAINING
# ============================================================
#
# Using existing model: best_emotion_model.pt
#
# To retrain, delete or rename the model file:
#   - best_emotion_model.pt
#   - emotion_runs/emotion_classifier/weights/best.pt

# %% [markdown]
# ## 4. Training (Run only if no model exists)
#
# **Note:** Skip this section if you already have a trained model!

# %%
# Initialize detector for training
detector_train = TwoStageEmotionDetector(
    face_model='yolov8n-face.pt',
    device='cuda'
)

# Configure your dataset path
dataset_path = "data"

# Check if dataset exists
if not Path(dataset_path).exists():
    print(f"\n⚠ Error: Dataset directory not found: {dataset_path}")
    print("Please create dataset with structure:")
    print("  data/")
    print("    train/")
    print("      angry/")
    print("      happy/")
    print("      ...")
    print("    test/")
    print("      angry/")
    print("      happy/")
    print("      ...")
else:
    # Train the emotion classifier
    results = detector_train.train_emotion_classifier(
        dataset_path,
        epochs=20,
        batch=64,
        imgsz=224,
        patience=15
    )
    
    # Validate trained model
    detector_train.validate_emotion_classifier(dataset_path)
    
    # Export model
    print("\n" + "="*60)
    print("EXPORTING MODEL")
    print("="*60 + "\n")
    detector_train.export_emotion_model(format='onnx')
    
    print("\n" + "="*60)
    print("TRAINING COMPLETE!")
    print("="*60)
    print("\nModel saved to root directory:")
    print("  - best_emotion_model.pt")
    print("  - best_emotion_model.onnx\n")
# Out:
# Using device: cuda
# Loading face detection model...
# ✓ Face detector loaded: yolov8n-face.pt
# ✓ Emotion classifier initialized for training
#
# ============================================================
# Training Emotion Classifier
# ============================================================
#
# New https://pypi.org/project/ultralytics/8.3.240 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.232  Python-3.13.7 torch-2.9.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=64, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=emotion_classifier4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=emotion_runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\train... found 28709 images in 7 classes
# val: None...
# test: C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\test... found 7178 images in 7 classes
# Overriding model.yaml nc=1000 with nc=7
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    339207  ultralytics.nn.modules.head.Classify         [256, 7]
# YOLOv8n-cls summary: 56 layers, 1,447,255 parameters, 1,447,255 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.61.2 ms, read: 3.81.2 MB/s, size: 1.7 KB)
# train: Scanning C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\train... 28709 images, 0 corrupt: 100% ━━━━━━━━━━━━ 28709/28709 31.9Mit/s 0.0s
# val: Fast image access  (ping: 0.10.1 ms, read: 2.90.4 MB/s, size: 1.8 KB)
# val: Scanning C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\test... 7178 images, 0 corrupt: 100% ━━━━━━━━━━━━ 7178/7178 4.7Mit/s 0.0s0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier4
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/50      0.75G      1.716         37        224: 100% ━━━━━━━━━━━━ 449/449 10.8it/s 41.6s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 17.8it/s 3.2s.2ss
#                    all       0.41      0.941
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/50     0.871G      1.454         37        224: 100% ━━━━━━━━━━━━ 449/449 12.3it/s 36.5s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.5it/s 2.9s0.1s
#                    all      0.493      0.972
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/50     0.871G      1.311         37        224: 100% ━━━━━━━━━━━━ 449/449 13.1it/s 34.2s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 20.0it/s 2.8s0.1s
#                    all      0.543      0.976
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/50     0.871G      1.239         37        224: 100% ━━━━━━━━━━━━ 449/449 12.6it/s 35.6s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.7it/s 2.9s0.2s
#                    all      0.586      0.983
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/50     0.871G      1.147         37        224: 100% ━━━━━━━━━━━━ 449/449 12.6it/s 35.5s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.5it/s 2.9s0.2s
#                    all      0.596      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/50     0.871G      1.093         37        224: 100% ━━━━━━━━━━━━ 449/449 12.4it/s 36.3s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.4it/s 2.9s0.1s
#                    all      0.615      0.985
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/50     0.871G      1.058         37        224: 100% ━━━━━━━━━━━━ 449/449 12.3it/s 36.6s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.2it/s 3.0s0.1s
#                    all      0.632      0.987
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/50     0.871G      1.031         37        224: 100% ━━━━━━━━━━━━ 449/449 12.3it/s 36.4s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.5it/s 2.9s0.1s
#                    all      0.625      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/50     0.871G      1.011         37        224: 100% ━━━━━━━━━━━━ 449/449 12.4it/s 36.3s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.7it/s 2.9s0.2s
#                    all      0.634      0.987
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/50     0.873G     0.9928         37        224: 100% ━━━━━━━━━━━━ 449/449 12.6it/s 35.5s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.3it/s 2.9s0.1s
#                    all      0.643      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/50     0.873G     0.9726         37        224: 100% ━━━━━━━━━━━━ 449/449 12.5it/s 35.8s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.0it/s 3.0s0.1s
#                    all      0.651       0.99
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/50     0.873G     0.9526         37        224: 100% ━━━━━━━━━━━━ 449/449 12.3it/s 36.4s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.4it/s 2.9s0.1s
#                    all      0.648      0.988
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/50     0.873G     0.9405         37        224: 100% ━━━━━━━━━━━━ 449/449 12.6it/s 35.5s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.5it/s 2.9s0.2s
#                    all      0.653       0.99
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/50     0.873G     0.9292         37        224: 100% ━━━━━━━━━━━━ 449/449 12.7it/s 35.4s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.6it/s 2.9s0.2s
#                    all      0.661      0.991
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/50     0.873G     0.9222         37        224: 100% ━━━━━━━━━━━━ 449/449 12.6it/s 35.7s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.0it/s 3.0s0.1s
#                    all      0.657      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/50     0.873G     0.9022         37        224: 100% ━━━━━━━━━━━━ 449/449 12.7it/s 35.4s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.6it/s 2.9s0.2s
#                    all      0.663      0.991
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/50     0.873G     0.8899         37        224: 100% ━━━━━━━━━━━━ 449/449 12.6it/s 35.5s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.2it/s 3.0s0.1s
#                    all       0.67       0.99
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/50     0.873G     0.8817         37        224: 100% ━━━━━━━━━━━━ 449/449 12.3it/s 36.5s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.0it/s 3.0s0.1s
#                    all       0.67      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/50     0.873G     0.8731         37        224: 100% ━━━━━━━━━━━━ 449/449 11.9it/s 37.8s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.6it/s 2.9s0.1s
#                    all      0.675      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/50     0.873G     0.8661         37        224: 100% ━━━━━━━━━━━━ 449/449 12.5it/s 35.9s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.5it/s 2.9s0.1s
#                    all      0.677      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/50     0.873G     0.8574         37        224: 100% ━━━━━━━━━━━━ 449/449 12.4it/s 36.1s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.0it/s 3.0s0.1s
#                    all      0.678      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/50     0.873G     0.8456         37        224: 100% ━━━━━━━━━━━━ 449/449 12.4it/s 36.3s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.5it/s 2.9s0.1s
#                    all      0.678      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/50     0.873G      0.834         37        224: 100% ━━━━━━━━━━━━ 449/449 12.3it/s 36.6s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.5it/s 2.9s0.1s
#                    all      0.683      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/50     0.873G     0.8281         37        224: 100% ━━━━━━━━━━━━ 449/449 12.6it/s 35.7s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.6it/s 2.9s0.2s
#                    all      0.684      0.991
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/50     0.873G     0.8191         37        224: 100% ━━━━━━━━━━━━ 449/449 12.2it/s 36.8s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.0it/s 3.0s0.1s
#                    all      0.684      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/50     0.873G     0.8056         37        224: 100% ━━━━━━━━━━━━ 449/449 12.4it/s 36.1s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.4it/s 2.9s0.1s
#                    all      0.688      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/50     0.873G      0.798         37        224: 100% ━━━━━━━━━━━━ 449/449 12.5it/s 35.9s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.2it/s 3.0s0.1s
#                    all      0.689      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/50     0.873G     0.7815         37        224: 100% ━━━━━━━━━━━━ 449/449 12.4it/s 36.1s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.7it/s 2.9s0.1s
#                    all      0.689      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/50     0.873G     0.7785         37        224: 100% ━━━━━━━━━━━━ 449/449 12.5it/s 36.0s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.6it/s 2.9s0.1s
#                    all      0.691      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/50     0.873G     0.7558         37        224: 100% ━━━━━━━━━━━━ 449/449 12.2it/s 36.7s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 18.7it/s 3.1s0.1s
#                    all      0.691      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       31/50     0.873G     0.7551         37        224: 100% ━━━━━━━━━━━━ 449/449 12.2it/s 36.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 18.1it/s 3.2s0.1s
#                    all      0.695      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       32/50     0.873G     0.7504         37        224: 100% ━━━━━━━━━━━━ 449/449 12.3it/s 36.4s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.5it/s 2.9s0.2s
#                    all      0.696      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       33/50     0.873G     0.7298         37        224: 100% ━━━━━━━━━━━━ 449/449 12.2it/s 36.7s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.1it/s 3.0s0.1s
#                    all      0.695      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       34/50     0.873G     0.7255         37        224: 100% ━━━━━━━━━━━━ 449/449 12.3it/s 36.5s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.6it/s 2.9s0.1s
#                    all      0.694      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       35/50     0.873G     0.7106         37        224: 100% ━━━━━━━━━━━━ 449/449 12.1it/s 37.1s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.4it/s 2.9s0.1s
#                    all      0.696      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       36/50     0.873G     0.6996         37        224: 100% ━━━━━━━━━━━━ 449/449 12.3it/s 36.5s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.6it/s 2.9s0.1s
#                    all      0.696      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       37/50     0.873G     0.6853         37        224: 100% ━━━━━━━━━━━━ 449/449 12.4it/s 36.3s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.0it/s 3.0s.2ss
#                    all      0.697      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       38/50     0.873G     0.6725         37        224: 100% ━━━━━━━━━━━━ 449/449 12.2it/s 36.7s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.2it/s 3.0s0.1s
#                    all      0.698      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       39/50     0.873G     0.6658         37        224: 100% ━━━━━━━━━━━━ 449/449 11.7it/s 38.4s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.2it/s 3.0s0.1s
#                    all      0.698      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       40/50     0.873G     0.6428         37        224: 100% ━━━━━━━━━━━━ 449/449 11.7it/s 38.3s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.2it/s 3.0s0.1s
#                    all      0.698      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       41/50     0.873G     0.6342         37        224: 100% ━━━━━━━━━━━━ 449/449 12.0it/s 37.3s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 18.4it/s 3.1s0.2s
#                    all      0.699      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       42/50     0.873G     0.6265         37        224: 100% ━━━━━━━━━━━━ 449/449 12.4it/s 36.3s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 18.8it/s 3.0s0.1s
#                    all      0.701      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       43/50     0.873G     0.6043         37        224: 100% ━━━━━━━━━━━━ 449/449 12.4it/s 36.3s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.0it/s 3.0s.1ss
#                    all      0.703      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       44/50     0.873G     0.5988         37        224: 100% ━━━━━━━━━━━━ 449/449 12.0it/s 37.5s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.0it/s 3.0s.2ss
#                    all      0.703      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       45/50     0.873G     0.5806         37        224: 100% ━━━━━━━━━━━━ 449/449 12.5it/s 35.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.4it/s 2.9s0.1s
#                    all      0.703      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       46/50     0.873G     0.5659         37        224: 100% ━━━━━━━━━━━━ 449/449 12.4it/s 36.2s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.0it/s 3.0s0.1s
#                    all      0.704      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       47/50     0.873G     0.5566         37        224: 100% ━━━━━━━━━━━━ 449/449 12.3it/s 36.5s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 18.8it/s 3.0s0.2s
#                    all      0.703      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       48/50     0.873G     0.5391         37        224: 100% ━━━━━━━━━━━━ 449/449 12.4it/s 36.1s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.4it/s 2.9s0.2s
#                    all      0.703      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       49/50     0.873G     0.5238         37        224: 100% ━━━━━━━━━━━━ 449/449 12.1it/s 37.0s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 19.0it/s 3.0s.1ss
#                    all      0.702      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       50/50     0.873G     0.5132         37        224: 100% ━━━━━━━━━━━━ 449/449 12.5it/s 36.0s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 18.8it/s 3.0s0.1s
#                    all      0.702      0.992
#
# 50 epochs completed in 0.569 hours.
# Optimizer stripped from C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier4\weights\last.pt, 3.0MB
# Optimizer stripped from C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier4\weights\best.pt, 3.0MB
#
# Validating C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier4\weights\best.pt...
# Ultralytics 8.3.232  Python-3.13.7 torch-2.9.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,443,847 parameters, 0 gradients, 3.3 GFLOPs
# WARNING Dataset 'split=val' not found, using 'split=test' instead.
# train: C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\train... found 28709 images in 7 classes
# val: C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\test... found 7178 images in 7 classes
# test: C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\test... found 7178 images in 7 classes
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 57/57 18.0it/s 3.2s.3ss
#                    all      0.704      0.993
# Speed: 0.1ms preprocess, 0.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier4
#
# ✓ Training completed!
# ✓ Best model automatically saved to: c:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\best_emotion_model.pt
#
# Validating emotion classifier...
# Ultralytics 8.3.232  Python-3.13.7 torch-2.9.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,443,847 parameters, 0 gradients, 3.3 GFLOPs
# WARNING Dataset 'split=val' not found, using 'split=test' instead.
# train: C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\train... found 28709 images in 7 classes
# val: C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\test... found 7178 images in 7 classes
# test: C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\test... found 7178 images in 7 classes
# val: Fast image access  (ping: 0.00.0 ms, read: 21.66.0 MB/s, size: 1.8 KB)
# val: Scanning C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\data\test... 7178 images, 0 corrupt: 100% ━━━━━━━━━━━━ 7178/7178 6.3Mit/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 449/449 77.1it/s 5.8s<0.0s
#                    all      0.704      0.992
# Speed: 0.1ms preprocess, 0.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\runs\classify\val16
#
# ============================================================
# EXPORTING MODEL
# ============================================================
#
# Exporting emotion classifier to onnx...
# Ultralytics 8.3.232  Python-3.13.7 torch-2.9.1+cu130 CPU (AMD Ryzen 7 7435HS)
#
# PyTorch: starting from 'C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier4\weights\best.pt' with input shape (1, 3, 224, 224) BCHW and output shape(s) (1, 7) (2.8 MB)
#
# ONNX: starting export with onnx 1.19.1 opset 22...
# ONNX: slimming with onnxslim 0.1.80...
# ONNX: export success  2.7s, saved as 'C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier4\weights\best.onnx' (5.5 MB)
#
# Export complete (2.8s)
# Results saved to C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier4\weights
# Predict:         yolo predict task=classify model=C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier4\weights\best.onnx imgsz=224
# Validate:        yolo val task=classify model=C:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\emotion_runs\emotion_classifier4\weights\best.onnx imgsz=224 data=data
# Visualize:       https://netron.app
# ✓ Export completed!
#
# ============================================================
# TRAINING COMPLETE!
# ============================================================
#
# Model saved to root directory:
#   - best_emotion_model.pt
#   - best_emotion_model.onnx

# %% [markdown]
# ## 5. Load Model for Inference

# %%
# Get the trained model path
model_path = check_trained_model()

if model_path is None:
    print("⚠ No trained model found! Please train a model first (Section 4)")
else:
    # Load trained models for inference
    detector = TwoStageEmotionDetector(
        face_model='yolov8n-face.pt',
        emotion_model=model_path,
        device='cuda'
    )
    
    print("\n" + "="*60)
    print("READY FOR INFERENCE!")
    print("="*60 + "\n")
# Out:
# ✓ Found trained model: c:\Users\nicho\Documents\GitHub_Repository\Python\2331182-Lab-AI\uas\best_emotion_model.pt
# Using device: cuda
# Loading face detection model...
# ✓ Face detector loaded: yolov8n-face.pt
# ✓ Emotion classifier loaded: best_emotion_model.pt
#
# ============================================================
# READY FOR INFERENCE!
# ============================================================

# %% [markdown]
# ## 8. Real-time Webcam Detection

# %%
# Real-time webcam detection
# Press 'q' to quit

detector.process_video(
    'webcam',
    conf_face=0.5,
    conf_emotion=0.3
)
# Out:
# Processing video... Press 'q' to quit
#
# Detected 1 face(s):
#   Face 1: neutral (34.93%)
#
# Detected 1 face(s):
#   Face 1: sad (34.52%)
#
# Detected 1 face(s):
#   Face 1: sad (43.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (34.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.79%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.79%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.98%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.98%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.74%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.74%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.52%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.52%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.59%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.59%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.56%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.56%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.27%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.27%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.83%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.83%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.83%)
#
# Detected 1 face(s):
#   Face 1: sad (39.45%)
#
# Detected 1 face(s):
#   Face 1: sad (39.45%)
#
# Detected 1 face(s):
#   Face 1: sad (39.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.38%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.38%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.38%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.83%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.83%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.83%)
#
# Detected 1 face(s):
#   Face 1: sad (42.23%)
#
# Detected 1 face(s):
#   Face 1: sad (42.23%)
#
# Detected 1 face(s):
#   Face 1: sad (42.23%)
#
# Detected 1 face(s):
#   Face 1: sad (53.76%)
#
# Detected 1 face(s):
#   Face 1: sad (53.76%)
#
# Detected 1 face(s):
#   Face 1: sad (53.76%)
#
# Detected 1 face(s):
#   Face 1: sad (52.41%)
#
# Detected 1 face(s):
#   Face 1: sad (52.41%)
#
# Detected 1 face(s):
#   Face 1: sad (52.41%)
#
# Detected 1 face(s):
#   Face 1: sad (54.51%)
#
# Detected 1 face(s):
#   Face 1: sad (54.51%)
#
# Detected 1 face(s):
#   Face 1: sad (54.51%)
#
# Detected 1 face(s):
#   Face 1: sad (39.54%)
#
# Detected 1 face(s):
#   Face 1: sad (39.54%)
#
# Detected 1 face(s):
#   Face 1: sad (39.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.38%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.38%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.38%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (34.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (34.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (34.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.10%)
#
# Detected 1 face(s):
#   Face 1: happy (46.74%)
#
# Detected 1 face(s):
#   Face 1: happy (46.74%)
#
# Detected 1 face(s):
#   Face 1: happy (46.74%)
#
# Detected 1 face(s):
#   Face 1: happy (59.76%)
#
# Detected 1 face(s):
#   Face 1: happy (59.76%)
#
# Detected 1 face(s):
#   Face 1: happy (59.76%)
#
# Detected 1 face(s):
#   Face 1: happy (60.31%)
#
# Detected 1 face(s):
#   Face 1: happy (60.31%)
#
# Detected 1 face(s):
#   Face 1: happy (60.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.47%)
#
# Detected 1 face(s):
#   Face 1: happy (43.44%)
#
# Detected 1 face(s):
#   Face 1: happy (43.44%)
#
# Detected 1 face(s):
#   Face 1: happy (43.44%)
#
# Detected 1 face(s):
#   Face 1: happy (56.78%)
#
# Detected 1 face(s):
#   Face 1: happy (56.78%)
#
# Detected 1 face(s):
#   Face 1: happy (60.66%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.43%)
#
# Detected 1 face(s):
#   Face 1: happy (47.62%)
#
# Detected 1 face(s):
#   Face 1: happy (47.62%)
#
# Detected 1 face(s):
#   Face 1: happy (47.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (81.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (81.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (81.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.20%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.20%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.24%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.24%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.24%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (32.54%)
#
# Detected 1 face(s):
#   Face 1: disgusted (74.54%)
#
# Detected 1 face(s):
#   Face 1: disgusted (74.54%)
#
# Detected 1 face(s):
#   Face 1: disgusted (74.54%)
#
# Detected 1 face(s):
#   Face 1: disgusted (62.74%)
#
# Detected 1 face(s):
#   Face 1: disgusted (62.74%)
#
# Detected 1 face(s):
#   Face 1: disgusted (62.74%)
#
# Detected 1 face(s):
#   Face 1: angry (48.28%)
#
# Detected 1 face(s):
#   Face 1: angry (48.28%)
#
# Detected 1 face(s):
#   Face 1: angry (48.28%)
#
# Detected 1 face(s):
#   Face 1: disgusted (58.61%)
#
# Detected 1 face(s):
#   Face 1: disgusted (58.61%)
#
# Detected 1 face(s):
#   Face 1: disgusted (68.04%)
#
# Detected 1 face(s):
#   Face 1: disgusted (59.40%)
#
# Detected 1 face(s):
#   Face 1: disgusted (59.40%)
#
# Detected 1 face(s):
#   Face 1: disgusted (59.40%)
#
# Detected 1 face(s):
#   Face 1: disgusted (76.21%)
#
# Detected 1 face(s):
#   Face 1: disgusted (76.21%)
#
# Detected 1 face(s):
#   Face 1: disgusted (76.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.74%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.74%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.74%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (33.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (33.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (33.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.44%)
#
# Detected 1 face(s):
#   Face 1: sad (58.61%)
#
# Detected 1 face(s):
#   Face 1: sad (58.61%)
#
# Detected 1 face(s):
#   Face 1: sad (58.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.21%)
#
# Detected 1 face(s):
#   Face 1: surprised (24.54%)
#
# Detected 1 face(s):
#   Face 1: surprised (24.54%)
#
# Detected 1 face(s):
#   Face 1: sad (67.72%)
#
# Detected 1 face(s):
#   Face 1: sad (67.72%)
#
# Detected 1 face(s):
#   Face 1: sad (67.72%)
#
# Detected 1 face(s):
#   Face 1: sad (70.04%)
#
# Detected 1 face(s):
#   Face 1: sad (70.04%)
#
# Detected 1 face(s):
#   Face 1: sad (70.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.43%)
#
# Detected 1 face(s):
#   Face 1: surprised (32.91%)
#
# Detected 1 face(s):
#   Face 1: surprised (32.91%)
#
# Detected 1 face(s):
#   Face 1: surprised (32.91%)
#
# Detected 1 face(s):
#   Face 1: surprised (47.04%)
#
# Detected 1 face(s):
#   Face 1: surprised (47.04%)
#
# Detected 1 face(s):
#   Face 1: surprised (47.04%)
#
# Detected 1 face(s):
#   Face 1: surprised (41.21%)
#
# Detected 1 face(s):
#   Face 1: surprised (41.21%)
#
# Detected 1 face(s):
#   Face 1: surprised (41.21%)
#
# Detected 1 face(s):
#   Face 1: surprised (28.16%)
#
# Detected 1 face(s):
#   Face 1: surprised (28.16%)
#
# Detected 1 face(s):
#   Face 1: surprised (28.16%)
#
# Detected 1 face(s):
#   Face 1: surprised (29.27%)
#
# Detected 1 face(s):
#   Face 1: surprised (29.27%)
#
# Detected 1 face(s):
#   Face 1: surprised (29.27%)
#
# Detected 1 face(s):
#   Face 1: sad (26.95%)
#
# Detected 1 face(s):
#   Face 1: sad (26.95%)
#
# Detected 1 face(s):
#   Face 1: sad (26.95%)
#
# Detected 1 face(s):
#   Face 1: sad (30.89%)
#
# Detected 1 face(s):
#   Face 1: sad (30.89%)
#
# Detected 1 face(s):
#   Face 1: sad (30.89%)
#
# Detected 1 face(s):
#   Face 1: surprised (31.83%)
#
# Detected 1 face(s):
#   Face 1: surprised (31.83%)
#
# Detected 1 face(s):
#   Face 1: surprised (31.83%)
#
# Detected 1 face(s):
#   Face 1: surprised (28.92%)
#
# Detected 1 face(s):
#   Face 1: surprised (28.92%)
#
# Detected 1 face(s):
#   Face 1: surprised (28.92%)
#
# Detected 1 face(s):
#   Face 1: sad (26.38%)
#
# Detected 1 face(s):
#   Face 1: sad (26.38%)
#
# Detected 1 face(s):
#   Face 1: sad (26.38%)
#
# Detected 1 face(s):
#   Face 1: surprised (34.07%)
#
# Detected 1 face(s):
#   Face 1: surprised (34.07%)
#
# Detected 1 face(s):
#   Face 1: surprised (34.07%)
#
# Detected 1 face(s):
#   Face 1: surprised (43.67%)
#
# Detected 1 face(s):
#   Face 1: surprised (43.67%)
#
# Detected 1 face(s):
#   Face 1: surprised (43.67%)
#
# Detected 1 face(s):
#   Face 1: sad (38.93%)
#
# Detected 1 face(s):
#   Face 1: sad (38.93%)
#
# Detected 1 face(s):
#   Face 1: sad (38.93%)
#
# Detected 1 face(s):
#   Face 1: sad (47.04%)
#
# Detected 1 face(s):
#   Face 1: sad (47.04%)
#
# Detected 1 face(s):
#   Face 1: sad (47.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.58%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.58%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.82%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.02%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.02%)
#
# Detected 1 face(s):
#   Face 1: neutral (74.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.64%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.64%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.41%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.41%)
#
# Detected 1 face(s):
#   Face 1: neutral (74.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (74.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (70.16%)
#
# Detected 1 face(s):
#   Face 1: neutral (70.16%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.18%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.18%)
#
# Detected 1 face(s):
#   Face 1: neutral (74.09%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.26%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.66%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.66%)
#
# Detected 1 face(s):
#   Face 1: neutral (74.63%)
#
# Detected 1 face(s):
#   Face 1: neutral (74.63%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.42%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.98%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.64%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (81.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.40%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (86.20%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (81.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (81.66%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.98%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (81.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (81.91%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.34%)
#
# Detected 1 face(s):
#   Face 1: neutral (74.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.81%)
#
# Detected 1 face(s):
#   Face 1: neutral (70.42%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.81%)
#
# Detected 1 face(s):
#   Face 1: neutral (74.81%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (86.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.40%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (70.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.27%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (81.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.40%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (89.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.50%)
#
# Detected 1 face(s):
#   Face 1: happy (49.35%)
#
# Detected 1 face(s):
#   Face 1: happy (49.35%)
#
# Detected 1 face(s):
#   Face 1: happy (62.62%)
#
# Detected 1 face(s):
#   Face 1: happy (57.20%)
#
# Detected 1 face(s):
#   Face 1: happy (63.29%)
#
# Detected 1 face(s):
#   Face 1: happy (63.65%)
#
# Detected 1 face(s):
#   Face 1: happy (61.46%)
#
# Detected 1 face(s):
#   Face 1: happy (62.92%)
#
# Detected 1 face(s):
#   Face 1: happy (57.23%)
#
# Detected 1 face(s):
#   Face 1: happy (74.54%)
#
# Detected 1 face(s):
#   Face 1: happy (72.19%)
#
# Detected 1 face(s):
#   Face 1: happy (75.30%)
#
# Detected 1 face(s):
#   Face 1: happy (71.05%)
#
# Detected 1 face(s):
#   Face 1: happy (58.89%)
#
# Detected 1 face(s):
#   Face 1: happy (63.25%)
#
# Detected 1 face(s):
#   Face 1: happy (67.16%)
#
# Detected 1 face(s):
#   Face 1: happy (67.41%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.83%)
#
# Detected 1 face(s):
#   Face 1: neutral (89.66%)
#
# Detected 1 face(s):
#   Face 1: neutral (91.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (91.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (70.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.75%)
#
# Detected 1 face(s):
#   Face 1: sad (44.57%)
#
# Detected 1 face(s):
#   Face 1: sad (60.78%)
#
# Detected 1 face(s):
#   Face 1: sad (47.82%)
#
# Detected 1 face(s):
#   Face 1: sad (54.55%)
#
# Detected 1 face(s):
#   Face 1: sad (67.43%)
#
# Detected 1 face(s):
#   Face 1: sad (70.21%)
#
# Detected 1 face(s):
#   Face 1: sad (60.46%)
#
# Detected 1 face(s):
#   Face 1: sad (65.65%)
#
# Detected 1 face(s):
#   Face 1: sad (67.00%)
#
# Detected 1 face(s):
#   Face 1: sad (67.50%)
#
# Detected 1 face(s):
#   Face 1: sad (65.19%)
#
# Detected 1 face(s):
#   Face 1: sad (62.61%)
#
# Detected 1 face(s):
#   Face 1: sad (64.01%)
#
# Detected 1 face(s):
#   Face 1: sad (61.25%)
#
# Detected 1 face(s):
#   Face 1: sad (65.33%)
#
# Detected 1 face(s):
#   Face 1: sad (68.13%)
#
# Detected 1 face(s):
#   Face 1: sad (62.05%)
#
# Detected 1 face(s):
#   Face 1: sad (68.87%)
#
# Detected 1 face(s):
#   Face 1: sad (64.29%)
#
# Detected 1 face(s):
#   Face 1: sad (64.25%)
#
# Detected 1 face(s):
#   Face 1: sad (58.97%)
#
# Detected 1 face(s):
#   Face 1: sad (55.19%)
#
# Detected 1 face(s):
#   Face 1: sad (63.93%)
#
# Detected 1 face(s):
#   Face 1: sad (66.31%)
#
# Detected 1 face(s):
#   Face 1: sad (59.27%)
#
# Detected 1 face(s):
#   Face 1: sad (59.27%)
#
# Detected 1 face(s):
#   Face 1: sad (60.14%)
#
# Detected 1 face(s):
#   Face 1: sad (53.88%)
#
# Detected 1 face(s):
#   Face 1: sad (57.17%)
#
# Detected 1 face(s):
#   Face 1: sad (52.30%)
#
# Detected 1 face(s):
#   Face 1: sad (61.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.56%)
#
# Detected 1 face(s):
#   Face 1: neutral (74.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.69%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.16%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.24%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.59%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.38%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.58%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.56%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.69%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.56%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.74%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.91%)
#
# Detected 1 face(s):
#   Face 1: neutral (87.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.40%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.69%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.00%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (88.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (81.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (89.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.87%)
#
# Detected 1 face(s):
#   Face 1: neutral (86.56%)
#
# Detected 1 face(s):
#   Face 1: neutral (87.16%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.40%)
#
# Detected 1 face(s):
#   Face 1: neutral (81.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (88.52%)
#
# Detected 1 face(s):
#   Face 1: neutral (87.09%)
#
# Detected 1 face(s):
#   Face 1: neutral (88.91%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (87.60%)
#
# Detected 1 face(s):
#   Face 1: neutral (88.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (90.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (88.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (87.27%)
#
# Detected 1 face(s):
#   Face 1: neutral (81.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (70.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (70.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.60%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.87%)
#
# Detected 1 face(s):
#   Face 1: neutral (74.66%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (87.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.27%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.34%)
#
# Detected 1 face(s):
#   Face 1: sad (43.14%)
#
# Detected 1 face(s):
#   Face 1: sad (44.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.42%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (74.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.66%)
#
# Detected 1 face(s):
#   Face 1: neutral (74.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.41%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.82%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.64%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.27%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.63%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.13%)
#
# Detected 1 face(s):
#   Face 1: sad (51.04%)
#
# Detected 1 face(s):
#   Face 1: sad (55.18%)
#
# Detected 1 face(s):
#   Face 1: sad (52.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.09%)
#
# Detected 1 face(s):
#   Face 1: sad (50.11%)
#
# Detected 1 face(s):
#   Face 1: sad (54.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.38%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.79%)
#
# Detected 1 face(s):
#   Face 1: sad (49.04%)
#
# Detected 1 face(s):
#   Face 1: sad (49.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.26%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.73%)
#
# Detected 1 face(s):
#   Face 1: sad (47.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.02%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.54%)
#
# Detected 1 face(s):
#   Face 1: sad (46.08%)
#
# Detected 1 face(s):
#   Face 1: sad (47.49%)
#
# Detected 1 face(s):
#   Face 1: sad (43.24%)
#
# Detected 1 face(s):
#   Face 1: sad (44.24%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.38%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.95%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.62%)
#
# Detected 1 face(s):
#   Face 1: sad (53.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.90%)
#
# Detected 1 face(s):
#   Face 1: sad (50.29%)
#
# Detected 1 face(s):
#   Face 1: sad (51.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.02%)
#
# Detected 1 face(s):
#   Face 1: sad (43.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.07%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.87%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.65%)
#
# Detected 1 face(s):
#   Face 1: sad (41.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.34%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.20%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.83%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.95%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.18%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.79%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.24%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.75%)
#
# Detected 1 face(s):
#   Face 1: sad (46.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.95%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.20%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.52%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.42%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.30%)
#
# Detected 1 face(s):
#   Face 1: sad (55.65%)
#
# Detected 1 face(s):
#   Face 1: sad (47.47%)
#
# Detected 1 face(s):
#   Face 1: sad (58.09%)
#
# Detected 1 face(s):
#   Face 1: sad (58.64%)
#
# Detected 1 face(s):
#   Face 1: sad (61.75%)
#
# Detected 1 face(s):
#   Face 1: sad (50.40%)
#
# Detected 1 face(s):
#   Face 1: sad (66.35%)
#
# Detected 1 face(s):
#   Face 1: sad (46.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.01%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.95%)
#
# Detected 1 face(s):
#   Face 1: sad (46.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.59%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.09%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.70%)
#
# Detected 1 face(s):
#   Face 1: sad (57.32%)
#
# Detected 1 face(s):
#   Face 1: sad (54.20%)
#
# Detected 1 face(s):
#   Face 1: sad (58.42%)
#
# Detected 1 face(s):
#   Face 1: sad (52.63%)
#
# Detected 1 face(s):
#   Face 1: sad (57.47%)
#
# Detected 1 face(s):
#   Face 1: sad (56.95%)
#
# Detected 1 face(s):
#   Face 1: sad (47.99%)
#
# Detected 1 face(s):
#   Face 1: sad (47.57%)
#
# Detected 1 face(s):
#   Face 1: sad (48.52%)
#
# Detected 1 face(s):
#   Face 1: sad (54.68%)
#
# Detected 1 face(s):
#   Face 1: sad (56.45%)
#
# Detected 1 face(s):
#   Face 1: sad (46.67%)
#
# Detected 1 face(s):
#   Face 1: sad (60.58%)
#
# Detected 1 face(s):
#   Face 1: sad (51.11%)
#
# Detected 1 face(s):
#   Face 1: sad (46.87%)
#
# Detected 1 face(s):
#   Face 1: sad (49.92%)
#
# Detected 1 face(s):
#   Face 1: sad (41.13%)
#
# Detected 1 face(s):
#   Face 1: sad (50.34%)
#
# Detected 1 face(s):
#   Face 1: sad (49.10%)
#
# Detected 1 face(s):
#   Face 1: sad (52.87%)
#
# Detected 1 face(s):
#   Face 1: sad (46.01%)
#
# Detected 1 face(s):
#   Face 1: sad (43.24%)
#
# Detected 1 face(s):
#   Face 1: sad (49.47%)
#
# Detected 1 face(s):
#   Face 1: sad (40.04%)
#
# Detected 1 face(s):
#   Face 1: sad (45.79%)
#
# Detected 1 face(s):
#   Face 1: sad (47.18%)
#
# Detected 1 face(s):
#   Face 1: sad (44.99%)
#
# Detected 1 face(s):
#   Face 1: sad (43.45%)
#
# Detected 1 face(s):
#   Face 1: sad (44.61%)
#
# Detected 1 face(s):
#   Face 1: sad (57.05%)
#
# Detected 1 face(s):
#   Face 1: sad (48.43%)
#
# Detected 1 face(s):
#   Face 1: sad (46.39%)
#
# Detected 1 face(s):
#   Face 1: sad (50.40%)
#
# Detected 1 face(s):
#   Face 1: sad (46.19%)
#
# Detected 1 face(s):
#   Face 1: sad (40.76%)
#
# Detected 1 face(s):
#   Face 1: sad (52.63%)
#
# Detected 1 face(s):
#   Face 1: sad (53.03%)
#
# Detected 1 face(s):
#   Face 1: sad (49.41%)
#
# Detected 1 face(s):
#   Face 1: sad (52.42%)
#
# Detected 1 face(s):
#   Face 1: sad (52.90%)
#
# Detected 1 face(s):
#   Face 1: sad (59.90%)
#
# Detected 1 face(s):
#   Face 1: sad (44.74%)
#
# Detected 1 face(s):
#   Face 1: angry (27.76%)
#
# Detected 1 face(s):
#   Face 1: sad (27.97%)
#
# Detected 1 face(s):
#   Face 1: angry (47.94%)
#
# Detected 1 face(s):
#   Face 1: angry (37.66%)
#
# Detected 1 face(s):
#   Face 1: angry (46.54%)
#
# Detected 1 face(s):
#   Face 1: angry (65.43%)
#
# Detected 1 face(s):
#   Face 1: angry (54.71%)
#
# Detected 1 face(s):
#   Face 1: angry (64.87%)
#
# Detected 1 face(s):
#   Face 1: angry (64.87%)
#
# Detected 1 face(s):
#   Face 1: angry (67.80%)
#
# Detected 1 face(s):
#   Face 1: angry (61.44%)
#
# Detected 1 face(s):
#   Face 1: angry (61.19%)
#
# Detected 1 face(s):
#   Face 1: angry (58.56%)
#
# Detected 1 face(s):
#   Face 1: angry (52.62%)
#
# Detected 1 face(s):
#   Face 1: angry (52.19%)
#
# Detected 1 face(s):
#   Face 1: angry (44.02%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.79%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.00%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.59%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.24%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.41%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.03%)
#
# Detected 1 face(s):
#   Face 1: sad (58.16%)
#
# Detected 1 face(s):
#   Face 1: sad (56.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.76%)
#
# Detected 1 face(s):
#   Face 1: sad (44.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.77%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (89.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.00%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (86.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.37%)
#
# Detected 1 face(s):
#   Face 1: neutral (87.82%)
#
# Detected 1 face(s):
#   Face 1: neutral (86.60%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (81.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.91%)
#
# Detected 1 face(s):
#   Face 1: neutral (70.69%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.74%)
#
# Detected 1 face(s):
#   Face 1: sad (42.06%)
#
# Detected 1 face(s):
#   Face 1: sad (37.57%)
#
# Detected 1 face(s):
#   Face 1: disgusted (33.24%)
#
# Detected 1 face(s):
#   Face 1: sad (46.92%)
#
# Detected 1 face(s):
#   Face 1: sad (43.24%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.74%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.02%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.79%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (86.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (88.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (86.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.63%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.26%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (74.26%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.26%)
#
# Detected 1 face(s):
#   Face 1: neutral (79.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (81.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.59%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (82.69%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (87.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (86.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (88.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (85.94%)
#
# Detected 1 face(s):
#   Face 1: neutral (80.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.94%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.75%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.67%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.26%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.95%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.83%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.34%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.64%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.87%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (30.18%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.82%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.27%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.30%)
#
# Detected 1 face(s):
#   Face 1: disgusted (31.80%)
#
# Detected 1 face(s):
#   Face 1: disgusted (31.80%)
#
# Detected 1 face(s):
#   Face 1: disgusted (30.68%)
#
# Detected 1 face(s):
#   Face 1: disgusted (37.36%)
#
# Detected 1 face(s):
#   Face 1: disgusted (33.56%)
#
# Detected 1 face(s):
#   Face 1: disgusted (37.64%)
#
# Detected 1 face(s):
#   Face 1: disgusted (35.31%)
#
# Detected 1 face(s):
#   Face 1: disgusted (52.09%)
#
# Detected 1 face(s):
#   Face 1: disgusted (47.70%)
#
# Detected 1 face(s):
#   Face 1: disgusted (49.14%)
#
# Detected 1 face(s):
#   Face 1: disgusted (55.34%)
#
# Detected 1 face(s):
#   Face 1: disgusted (84.72%)
#
# Detected 1 face(s):
#   Face 1: disgusted (70.77%)
#
# Detected 1 face(s):
#   Face 1: disgusted (83.17%)
#
# Detected 1 face(s):
#   Face 1: disgusted (90.22%)
#
# Detected 1 face(s):
#   Face 1: disgusted (85.58%)
#
# Detected 1 face(s):
#   Face 1: disgusted (90.92%)
#
# Detected 1 face(s):
#   Face 1: disgusted (89.61%)
#
# Detected 1 face(s):
#   Face 1: disgusted (85.60%)
#
# Detected 1 face(s):
#   Face 1: disgusted (89.53%)
#
# Detected 1 face(s):
#   Face 1: disgusted (89.32%)
#
# Detected 1 face(s):
#   Face 1: disgusted (83.88%)
#
# Detected 1 face(s):
#   Face 1: disgusted (89.64%)
#
# Detected 1 face(s):
#   Face 1: disgusted (85.36%)
#
# Detected 1 face(s):
#   Face 1: disgusted (89.79%)
#
# Detected 1 face(s):
#   Face 1: disgusted (81.49%)
#
# Detected 1 face(s):
#   Face 1: disgusted (69.53%)
#
# Detected 1 face(s):
#   Face 1: disgusted (57.83%)
#
# Detected 1 face(s):
#   Face 1: disgusted (45.09%)
#
# Detected 1 face(s):
#   Face 1: disgusted (32.85%)
#
# Detected 1 face(s):
#   Face 1: sad (25.41%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.49%)
#
# Detected 1 face(s):
#   Face 1: disgusted (35.32%)
#
# Detected 1 face(s):
#   Face 1: disgusted (47.27%)
#
# Detected 1 face(s):
#   Face 1: disgusted (41.58%)
#
# Detected 1 face(s):
#   Face 1: sad (25.68%)
#
# Detected 1 face(s):
#   Face 1: disgusted (52.69%)
#
# Detected 1 face(s):
#   Face 1: disgusted (62.06%)
#
# Detected 1 face(s):
#   Face 1: disgusted (47.57%)
#
# Detected 1 face(s):
#   Face 1: disgusted (48.57%)
#
# Detected 1 face(s):
#   Face 1: disgusted (41.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (31.92%)
#
# Detected 1 face(s):
#   Face 1: disgusted (33.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (32.36%)
#
# Detected 1 face(s):
#   Face 1: sad (28.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.63%)
# ...
#
# Detected 1 face(s):
#   Face 1: neutral (62.20%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.59%)
#
# Detected 1 face(s):
#   Face 1: sad (40.75%)
#
# Detected 1 face(s):
#   Face 1: sad (47.89%)
#
# Detected 1 face(s):
#   Face 1: sad (52.53%)
#
# Detected 1 face(s):
#   Face 1: sad (38.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.34%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.00%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.63%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.50%)
#
# Detected 1 face(s):
#   Face 1: neutral (77.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (76.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.25%)
#
# Detected 1 face(s):
#   Face 1: angry (43.54%)
#
# Detected 1 face(s):
#   Face 1: angry (34.78%)
#
# Detected 1 face(s):
#   Face 1: angry (42.66%)
#
# Detected 1 face(s):
#   Face 1: angry (52.52%)
#
# Detected 1 face(s):
#   Face 1: angry (43.83%)
#
# Detected 1 face(s):
#   Face 1: angry (49.82%)
#
# Detected 1 face(s):
#   Face 1: angry (50.84%)
#
# Detected 1 face(s):
#   Face 1: angry (36.62%)
#
# Detected 1 face(s):
#   Face 1: angry (36.71%)
#
# Detected 1 face(s):
#   Face 1: disgusted (38.84%)
#
# Detected 1 face(s):
#   Face 1: disgusted (46.26%)
#
# Detected 1 face(s):
#   Face 1: disgusted (39.53%)
#
# Detected 1 face(s):
#   Face 1: angry (48.63%)
#
# Detected 1 face(s):
#   Face 1: disgusted (63.68%)
#
# Detected 1 face(s):
#   Face 1: angry (50.89%)
#
# Detected 1 face(s):
#   Face 1: disgusted (48.97%)
#
# Detected 1 face(s):
#   Face 1: angry (39.49%)
#
# Detected 1 face(s):
#   Face 1: angry (31.27%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.42%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (78.94%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (70.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.74%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.88%)
#
# Detected 1 face(s):
#   Face 1: sad (51.13%)
#
# Detected 1 face(s):
#   Face 1: sad (44.49%)
#
# Detected 1 face(s):
#   Face 1: sad (48.22%)
#
# Detected 1 face(s):
#   Face 1: sad (48.83%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.54%)
#
# Detected 1 face(s):
#   Face 1: sad (36.91%)
#
# Detected 1 face(s):
#   Face 1: sad (36.90%)
#
# Detected 1 face(s):
#   Face 1: sad (31.80%)
#
# Detected 1 face(s):
#   Face 1: sad (33.40%)
#
# Detected 1 face(s):
#   Face 1: sad (29.93%)
#
# Detected 1 face(s):
#   Face 1: sad (30.52%)
#
# Detected 1 face(s):
#   Face 1: sad (32.80%)
#
# Detected 1 face(s):
#   Face 1: sad (39.47%)
#
# Detected 1 face(s):
#   Face 1: sad (27.59%)
#
# Detected 1 face(s):
#   Face 1: sad (34.44%)
#
# Detected 1 face(s):
#   Face 1: sad (41.60%)
#
# Detected 1 face(s):
#   Face 1: sad (34.28%)
#
# Detected 1 face(s):
#   Face 1: sad (34.97%)
#
# Detected 1 face(s):
#   Face 1: sad (33.82%)
#
# Detected 1 face(s):
#   Face 1: sad (36.81%)
#
# Detected 1 face(s):
#   Face 1: neutral (25.12%)
#
# Detected 1 face(s):
#   Face 1: sad (37.17%)
#
# Detected 1 face(s):
#   Face 1: sad (31.64%)
#
# Detected 1 face(s):
#   Face 1: neutral (31.73%)
#
# Detected 1 face(s):
#   Face 1: sad (41.59%)
#
# Detected 1 face(s):
#   Face 1: sad (41.81%)
#
# Detected 1 face(s):
#   Face 1: sad (41.54%)
#
# Detected 1 face(s):
#   Face 1: sad (36.41%)
#
# Detected 1 face(s):
#   Face 1: sad (41.89%)
#
# Detected 1 face(s):
#   Face 1: sad (36.87%)
#
# Detected 1 face(s):
#   Face 1: sad (31.54%)
#
# Detected 1 face(s):
#   Face 1: sad (53.21%)
#
# Detected 1 face(s):
#   Face 1: sad (53.21%)
#
# Detected 1 face(s):
#   Face 1: sad (53.61%)
#
# Detected 1 face(s):
#   Face 1: sad (55.27%)
#
# Detected 1 face(s):
#   Face 1: sad (37.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.96%)
#
# Detected 1 face(s):
#   Face 1: sad (47.72%)
#
# Detected 1 face(s):
#   Face 1: sad (36.18%)
#
# Detected 1 face(s):
#   Face 1: sad (42.20%)
#
# Detected 1 face(s):
#   Face 1: sad (31.03%)
#
# Detected 1 face(s):
#   Face 1: sad (38.31%)
#
# Detected 1 face(s):
#   Face 1: sad (40.60%)
#
# Detected 1 face(s):
#   Face 1: sad (45.00%)
#
# Detected 1 face(s):
#   Face 1: sad (46.09%)
#
# Detected 1 face(s):
#   Face 1: sad (47.48%)
#
# Detected 1 face(s):
#   Face 1: sad (54.23%)
#
# Detected 1 face(s):
#   Face 1: sad (43.21%)
#
# Detected 1 face(s):
#   Face 1: sad (46.92%)
#
# Detected 1 face(s):
#   Face 1: sad (41.96%)
#
# Detected 1 face(s):
#   Face 1: sad (40.43%)
#
# Detected 1 face(s):
#   Face 1: sad (40.99%)
#
# Detected 1 face(s):
#   Face 1: sad (40.99%)
#
# Detected 1 face(s):
#   Face 1: sad (44.38%)
#
# Detected 1 face(s):
#   Face 1: sad (48.66%)
#
# Detected 1 face(s):
#   Face 1: sad (55.02%)
#
# Detected 1 face(s):
#   Face 1: sad (48.76%)
#
# Detected 1 face(s):
#   Face 1: sad (48.66%)
#
# Detected 1 face(s):
#   Face 1: sad (50.77%)
#
# Detected 1 face(s):
#   Face 1: sad (51.70%)
#
# Detected 1 face(s):
#   Face 1: sad (55.33%)
#
# Detected 1 face(s):
#   Face 1: sad (54.21%)
#
# Detected 1 face(s):
#   Face 1: sad (57.42%)
#
# Detected 1 face(s):
#   Face 1: sad (46.99%)
#
# Detected 1 face(s):
#   Face 1: sad (50.54%)
#
# Detected 1 face(s):
#   Face 1: sad (54.12%)
#
# Detected 1 face(s):
#   Face 1: sad (62.92%)
#
# Detected 1 face(s):
#   Face 1: sad (61.26%)
#
# Detected 1 face(s):
#   Face 1: sad (44.90%)
#
# Detected 1 face(s):
#   Face 1: sad (46.82%)
#
# Detected 1 face(s):
#   Face 1: sad (48.92%)
#
# Detected 1 face(s):
#   Face 1: sad (47.62%)
#
# Detected 1 face(s):
#   Face 1: sad (44.32%)
#
# Detected 1 face(s):
#   Face 1: sad (54.53%)
#
# Detected 1 face(s):
#   Face 1: sad (50.30%)
#
# Detected 1 face(s):
#   Face 1: sad (55.07%)
#
# Detected 1 face(s):
#   Face 1: sad (55.92%)
#
# Detected 1 face(s):
#   Face 1: sad (58.27%)
#
# Detected 1 face(s):
#   Face 1: sad (48.01%)
#
# Detected 1 face(s):
#   Face 1: sad (52.52%)
#
# Detected 1 face(s):
#   Face 1: sad (46.28%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.40%)
#
# Detected 1 face(s):
#   Face 1: sad (51.40%)
#
# Detected 1 face(s):
#   Face 1: sad (51.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.10%)
#
# Detected 1 face(s):
#   Face 1: sad (35.01%)
#
# Detected 1 face(s):
#   Face 1: sad (35.45%)
#
# Detected 1 face(s):
#   Face 1: sad (32.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.90%)
#
# Detected 1 face(s):
#   Face 1: sad (68.25%)
#
# Detected 1 face(s):
#   Face 1: sad (51.98%)
#
# Detected 1 face(s):
#   Face 1: sad (53.43%)
#
# Detected 1 face(s):
#   Face 1: sad (47.96%)
#
# Detected 1 face(s):
#   Face 1: sad (43.34%)
#
# Detected 1 face(s):
#   Face 1: sad (47.53%)
#
# Detected 2 face(s):
#   Face 1: sad (45.42%)
#   Face 2: neutral (39.36%)
#
# Detected 1 face(s):
#   Face 1: sad (54.74%)
#
# Detected 1 face(s):
#   Face 1: sad (72.53%)
#
# Detected 1 face(s):
#   Face 1: sad (61.59%)
#
# Detected 1 face(s):
#   Face 1: sad (66.23%)
#
# Detected 1 face(s):
#   Face 1: sad (76.05%)
#
# Detected 1 face(s):
#   Face 1: sad (50.48%)
#
# Detected 1 face(s):
#   Face 1: sad (32.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.24%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.09%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.99%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.21%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.66%)
#
# Detected 1 face(s):
#   Face 1: angry (42.86%)
#
# Detected 1 face(s):
#   Face 1: angry (37.30%)
#
# Detected 1 face(s):
#   Face 1: angry (50.38%)
#
# Detected 1 face(s):
#   Face 1: angry (53.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.82%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.52%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.88%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (89.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (87.84%)
#
# Detected 1 face(s):
#   Face 1: neutral (88.20%)
#
# Detected 1 face(s):
#   Face 1: neutral (84.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.44%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.00%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.81%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.87%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.32%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.94%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (70.09%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.20%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.51%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.83%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.31%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.58%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.63%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.54%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.39%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (51.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.76%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.94%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.04%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.73%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.56%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (53.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.08%)
#
# Detected 1 face(s):
#   Face 1: neutral (40.58%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.57%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.34%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.27%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.64%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.72%)
#
# Detected 1 face(s):
#   Face 1: neutral (72.74%)
#
# Detected 1 face(s):
#   Face 1: neutral (75.60%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.20%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.19%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.45%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.13%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.35%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.23%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.36%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.79%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (67.26%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.64%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.22%)
#
# Detected 1 face(s):
#   Face 1: neutral (71.14%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.34%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (68.43%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.86%)
#
# Detected 1 face(s):
#   Face 1: neutral (58.95%)
#
# Detected 1 face(s):
#   Face 1: neutral (62.80%)
#
# Detected 1 face(s):
#   Face 1: neutral (59.85%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (65.89%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.26%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.81%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.95%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (63.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (83.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (61.64%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.68%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.11%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.16%)
#
# Detected 1 face(s):
#   Face 1: neutral (32.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.53%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.05%)
#
# Detected 1 face(s):
#   Face 1: neutral (42.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.46%)
#
# Detected 1 face(s):
#   Face 1: neutral (34.02%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (47.10%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (45.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (44.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.61%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.78%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.33%)
#
# Detected 1 face(s):
#   Face 1: neutral (34.65%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (37.41%)
#
# Detected 1 face(s):
#   Face 1: neutral (41.83%)
#
# Detected 1 face(s):
#   Face 1: neutral (31.29%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.71%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.70%)
#
# Detected 1 face(s):
#   Face 1: neutral (52.97%)
#
# Detected 1 face(s):
#   Face 1: neutral (66.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.17%)
#
# Detected 1 face(s):
#   Face 1: neutral (38.62%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.64%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.03%)
#
# Detected 1 face(s):
#   Face 1: neutral (54.49%)
#
# Detected 1 face(s):
#   Face 1: neutral (60.91%)
#
# Detected 1 face(s):
#   Face 1: neutral (35.92%)
#
# Detected 1 face(s):
#   Face 1: neutral (57.00%)
#
# Detected 1 face(s):
#   Face 1: neutral (43.91%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.93%)
#
# Detected 1 face(s):
#   Face 1: neutral (73.15%)
#
# Detected 1 face(s):
#   Face 1: neutral (50.47%)
#
# Detected 1 face(s):
#   Face 1: neutral (46.55%)
#
# Detected 1 face(s):
#   Face 1: neutral (39.96%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.48%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.06%)
#
# Detected 1 face(s):
#   Face 1: neutral (48.25%)
#
# Detected 1 face(s):
#   Face 1: neutral (56.30%)
#
# Detected 1 face(s):
#   Face 1: neutral (36.60%)
#
# Detected 1 face(s):
#   Face 1: neutral (49.56%)
#
# Detected 1 face(s):
#   Face 1: neutral (55.52%)
#
# Detected 1 face(s):
#   Face 1: neutral (69.12%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.90%)
#
# Detected 1 face(s):
#   Face 1: neutral (64.64%)
#
# ✓ Video processing completed! Processed 2485 frames

# %% [markdown]
# ## 10. Copy Training Metrics to Root Directory

# %%
# Copy training metrics to root directory for easy access
import shutil
from pathlib import Path

results_path = Path('emotion_runs/emotion_classifier')

if results_path.exists():
    print("Copying training metrics to root directory...\n")
    
    # Files to copy
    files_to_copy = {
        'confusion_matrix.png': 'confusion_matrix.png',
        'confusion_matrix_normalized.png': 'confusion_matrix_normalized.png',
        'results.png': 'training_results.png',
        'results.csv': 'training_results.csv'
    }
    
    copied_files = []
    
    for src_name, dst_name in files_to_copy.items():
        src_path = results_path / src_name
        dst_path = Path(dst_name)
        
        if src_path.exists():
            shutil.copy2(src_path, dst_path)
            copied_files.append(dst_name)
            print(f"✓ Copied: {dst_name}")
        else:
            print(f"⚠ Not found: {src_name}")
    
    if copied_files:
        print(f"\n✓ Successfully copied {len(copied_files)} file(s) to root directory!")
        print("\nFiles in root directory:")
        for file in copied_files:
            print(f"  - {file}")
    else:
        print("\n⚠ No files were copied.")
else:
    print("⚠ No training results found. Train a model first (Section 4)!")
# Out:
# Copying training metrics to root directory...
#
# ⚠ Not found: confusion_matrix.png
# ⚠ Not found: confusion_matrix_normalized.png
# ⚠ Not found: results.png
# ✓ Copied: training_results.csv
#
# ✓ Successfully copied 1 file(s) to root directory!
#
# Files in root directory:
#   - training_results.csv

# %% [markdown]
# ## 11. Display Training Metrics

# %%
# ===== SEABORN TRAINING RESULTS VISUALIZATION (ONE CELL) =====

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# IMPORTANT for Jupyter
# %matplotlib inline

sns.set_theme(style="whitegrid", font_scale=1.1)

# Locate results.csv
csv_paths = [
    Path("training_results.csv"),
    Path("emotion_runs/emotion_classifier/results.csv")
]

csv_path = None
for p in csv_paths:
    if p.exists():
        csv_path = p
        break

if csv_path is None:
    raise FileNotFoundError("❌ results.csv not found. Train model first.")

print(f"✓ Using training log: {csv_path}")

# Load data
df = pd.read_csv(csv_path)
df.columns = df.columns.str.strip()

# ===================== Accuracy Plot =====================
plt.figure(figsize=(8, 4))
sns.lineplot(
    data=df,
    x="epoch",
    y="metrics/accuracy_top1",
    marker="o"
)
plt.title("Training Accuracy (Top-1)")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.tight_layout()
plt.show()

# ===================== Loss Plot =====================
plt.figure(figsize=(8, 4))
sns.lineplot(
    data=df,
    x="epoch",
    y="train/loss",
    marker="o",
    label="Train Loss"
)

# Validation loss may or may not exist
if "val/loss" in df.columns:
    sns.lineplot(
        data=df,
        x="epoch",
        y="val/loss",
        marker="o",
        label="Val Loss"
    )

plt.title("Training Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.tight_layout()
plt.show()

# ===================== Best Epoch Summary =====================
best_idx = df["metrics/accuracy_top1"].idxmax()
best_epoch = int(df.loc[best_idx, "epoch"])
best_acc = df.loc[best_idx, "metrics/accuracy_top1"]

print("=" * 60)
print(f"✓ Best Accuracy : {best_acc:.4f}")
print(f"✓ Best Epoch   : {best_epoch}")
p
# Out:
# ✓ Using training log: training_results.csv
# ============================================================
# ✓ Best Accuracy : 0.6591
# ✓ Best Epoch   : 10
# WindowsPath('training_results.csv')

# %% [markdown]
# ## 12. View Training Results CSV

# %%
# Display training metrics as a table
import pandas as pd
from pathlib import Path

# Try to find results.csv
csv_paths = [
    Path('training_results.csv'),
    Path('emotion_runs/emotion_classifier/results.csv')
]

csv_path = None
for path in csv_paths:
    if path.exists():
        csv_path = path
        break

if csv_path:
    print("Training Metrics Summary:")
    print("="*60 + "\n")
    
    df = pd.read_csv(csv_path)
    
    # Clean column names (remove extra spaces)
    df.columns = df.columns.str.strip()
    
    # Display first few rows
    print("First 5 epochs:")
    display(df.head())
    
    # Display last few rows
    print("\nLast 5 epochs:")
    display(df.tail())
    
    # Find best epoch
    if 'metrics/accuracy_top1' in df.columns:
        best_idx = df['metrics/accuracy_top1'].idxmax()
        best_acc = df.loc[best_idx, 'metrics/accuracy_top1']
        best_epoch = df.loc[best_idx, 'epoch']
        
        print(f"\n" + "="*60)
        print(f"✓ Best Accuracy: {best_acc:.4f} at Epoch {int(best_epoch)}")
        print("="*60)
else:
    print("⚠ Training results CSV not found!")
    print("Train a model first or copy metrics to root directory.")
# Out:
# Training Metrics Summary:
# ============================================================
#
# First 5 epochs:
#    epoch      time  train/loss  metrics/accuracy_top1  metrics/accuracy_top5  \
# 0      1   36.4476     1.62994                0.52536                0.97311
# 1      2   66.6367     1.24818                0.58080                0.98272
# 2      3   96.2506     1.14115                0.59390                0.98579
# 3      4  125.4580     1.09795                0.61382                0.98718
# 4      5  154.9770     1.05547                0.62789                0.98579
#
#    val/loss    lr/pg0    lr/pg1    lr/pg2
# 0   1.24707  0.000302  0.000302  0.000302
# 1   1.10580  0.000575  0.000575  0.000575
# 2   1.06182  0.000818  0.000818  0.000818
# 3   1.00812  0.000774  0.000774  0.000774
# 4   0.99829  0.000729  0.000729  0.000729
# Last 5 epochs:
#    epoch     time  train/loss  metrics/accuracy_top1  metrics/accuracy_top5  \
# 5      6  183.845     1.01587                0.63945                0.98844
# 6      7  213.314     0.97888                0.64252                0.99136
# 7      8  242.054     0.96180                0.64795                0.99039
# 8      9  270.872     0.94185                0.65506                0.99122
# 9     10  300.017     0.91705                0.65910                0.99136
#
#    val/loss    lr/pg0    lr/pg1    lr/pg2
# 5   0.96691  0.000684  0.000684  0.000684
# 6   0.95647  0.000639  0.000639  0.000639
# 7   0.94279  0.000594  0.000594  0.000594
# 8   0.93069  0.000549  0.000549  0.000549
# 9   0.92113  0.000504  0.000504  0.000504
# ============================================================
# ✓ Best Accuracy: 0.6591 at Epoch 10
# ============================================================
